# %%
import tensorflow as tf
import cv2
import os
CATEGORIES = ["electron","muon"]

def prepare(filepath):
    
    
    img_array = cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
    new_array1 = cv2.resize(img_array,(120,50))
    new_array2 = cv2.resize(img_array,(120,50))
    new_array1=new_array1.reshape(50,120,1)
    new_array2=new_array2.reshape(50,120,1)
   
    new_array = np.concatenate([new_array2,new_array1],axis=0)
    
    
    
    new_array=new_array.reshape(2,50,120,1)
    new_array=np.transpose(new_array, (3, 1, 2,0))
    return new_array

# %%
model = tf.keras.models.load_model("CNN-Det_tf_lappd5x5-improvement_EnergyTester_V2-val-acc_0.94.model")

# %%
import numpy as np

# %%
CATEGORIES = ["electron","muon"]
prediction = model.predict([prepare('411.jpg')])

# %%
prediction
# Out:
# array([[0., 1.]], dtype=float32)

# %%
plt.imshow(prepare('411.jpg')[0,:,:,0], cmap='gray', interpolation='None')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img_array, cmap='gray', interpolation='None')

# %%
plt.imshow(new_array1, cmap='gray', interpolation='None')

# %%
new_array1=new_array1.reshape(50,120,1)
plt.imshow(new_array1[:,:,0], cmap='gray', interpolation='None')
