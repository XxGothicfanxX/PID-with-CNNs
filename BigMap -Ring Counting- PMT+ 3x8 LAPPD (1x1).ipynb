# %% [markdown]
# # Creation and Saving of combined Arrays from LAPPD 1x1 and PMT Data
#
# PMT Data is made out of Middle PMTs + Top/Bottom PMTs
#
# LAPPD Data is made out of 24 LAPPDs with 10x10 Resoultion and are in 8 columns  with 3 rows of LAPPDs divided
#
# 1. Import
# 2. Pure LAPPD Image (*become a little bit irrelevant*)
# 3. PMT+LAPPD Image without empty rows -> _No Fill_
# 4. PMT+LAPPD Image with empty rows -> _With fill_
# 5. Pure PMT Image

# %% [markdown]
# # 1) Import

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import copy
import random
import time
from collections import defaultdict
from tqdm.notebook import tqdm
import h5py
import pickle

# %% [markdown]
# # 2) Pure LAPPD Image
# 1x1 resolution

# %%
b=0
LAPPDres=0
bE=0
#batchsize=len(all_values)
#batchsize=120005
LAPPDres2=1
Zusatz=0
Fill=0
for i in tqdm(range(1)):
    
    
    all_values_Lappd = np.load('BeamRingCounting/Temp/ChargeLAPPD.npy')
    
    batchsize=len(all_values_Lappd)
    bE=bE+batchsize

    LAPPD1array = all_values_Lappd[b:bE,0].reshape(-1,1,1,1)
    LAPPD2array = all_values_Lappd[b:bE,1].reshape(-1,1,1,1)
    LAPPD3array = all_values_Lappd[b:bE,2].reshape(-1,1,1,1)
    LAPPD4array = all_values_Lappd[b:bE,3].reshape(-1,1,1,1)
    LAPPD5array = all_values_Lappd[b:bE,4].reshape(-1,1,1,1)
    LAPPD6array = all_values_Lappd[b:bE,5].reshape(-1,1,1,1)
    LAPPD7array = all_values_Lappd[b:bE,6].reshape(-1,1,1,1)
    LAPPD8array = all_values_Lappd[b:bE,7].reshape(-1,1,1,1)
    LAPPD9array = all_values_Lappd[b:bE,8].reshape(-1,1,1,1)
    LAPPD10array = all_values_Lappd[b:bE,9].reshape(-1,1,1,1)
    LAPPD11array = all_values_Lappd[b:bE,10].reshape(-1,1,1,1)
    LAPPD12array = all_values_Lappd[b:bE,11].reshape(-1,1,1,1)
    LAPPD13array = all_values_Lappd[b:bE,12].reshape(-1,1,1,1)
    LAPPD14array = all_values_Lappd[b:bE,13].reshape(-1,1,1,1)
    LAPPD15array = all_values_Lappd[b:bE,14].reshape(-1,1,1,1)
    LAPPD16array = all_values_Lappd[b:bE,15].reshape(-1,1,1,1)
    LAPPD17array = all_values_Lappd[b:bE,16].reshape(-1,1,1,1)
    LAPPD18array = all_values_Lappd[b:bE,17].reshape(-1,1,1,1)
    LAPPD19array = all_values_Lappd[b:bE,18].reshape(-1,1,1,1)
    LAPPD20array = all_values_Lappd[b:bE,19].reshape(-1,1,1,1)
    LAPPD21array = all_values_Lappd[b:bE,20].reshape(-1,1,1,1)
    LAPPD22array = all_values_Lappd[b:bE,21].reshape(-1,1,1,1)
    LAPPD23array = all_values_Lappd[b:bE,22].reshape(-1,1,1,1)
    LAPPD24array = all_values_Lappd[b:bE,23].reshape(-1,1,1,1)

    LAPPD1array = np.flip(np.flip(LAPPD1array,2),1)
    LAPPD2array = np.flip(np.flip(LAPPD2array,2),1)
    LAPPD3array = np.flip(np.flip(LAPPD3array,2),1)
    LAPPD4array = np.flip(np.flip(LAPPD4array,2),1)
    LAPPD5array = np.flip(np.flip(LAPPD5array,2),1)
    LAPPD6array = np.flip(np.flip(LAPPD6array,2),1)
    LAPPD7array = np.flip(np.flip(LAPPD7array,2),1)
    LAPPD8array = np.flip(np.flip(LAPPD8array,2),1)
    LAPPD9array = np.flip(np.flip(LAPPD9array,2),1)
    LAPPD10array = np.flip(np.flip(LAPPD10array,2),1)
    LAPPD11array = np.flip(np.flip(LAPPD11array,2),1)
    LAPPD12array = np.flip(np.flip(LAPPD12array,2),1)
    LAPPD13array = np.flip(np.flip(LAPPD13array,2),1)
    LAPPD14array = np.flip(np.flip(LAPPD14array,2),1)
    LAPPD15array = np.flip(np.flip(LAPPD15array,2),1)
    LAPPD16array = np.flip(np.flip(LAPPD16array,2),1)
    LAPPD17array = np.flip(np.flip(LAPPD17array,2),1)
    LAPPD18array = np.flip(np.flip(LAPPD18array,2),1)
    LAPPD19array = np.flip(np.flip(LAPPD19array,2),1)
    LAPPD20array = np.flip(np.flip(LAPPD20array,2),1)
    LAPPD21array = np.flip(np.flip(LAPPD21array,2),1)
    LAPPD22array = np.flip(np.flip(LAPPD22array,2),1)
    LAPPD23array = np.flip(np.flip(LAPPD23array,2),1)
    LAPPD24array = np.flip(np.flip(LAPPD24array,2),1)
    
    a=len(LAPPD1array)

 

    LP1=np.concatenate([LAPPD3array,LAPPD2array,LAPPD1array], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([LAPPD6array,LAPPD5array,LAPPD4array], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([LAPPD9array,LAPPD8array,LAPPD7array], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([LAPPD12array,LAPPD11array,LAPPD10array], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([LAPPD15array,LAPPD14array,LAPPD13array], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([LAPPD18array,LAPPD17array,LAPPD16array], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([LAPPD21array,LAPPD20array,LAPPD19array], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([LAPPD24array,LAPPD23array,LAPPD22array], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array

    del all_values_Lappd  
    #print("LAPPD Zyklus fertig: {}".format(i))
    
    

    
    
    
    fertig=np.concatenate([LP1,LP2,LP3,LP4,LP5,LP6,LP7,LP8],axis=2)
    del LP1,LP2,LP3,LP4,LP5,LP6,LP7,LP8
    
    print(fertig.shape)
    
    ############################################### TIME #################################
    
    
    all_values_Lappd = np.load('BeamRingCounting/Temp/TimeLAPPD_flipped.npy')
    
    
    
    LAPPD1array = all_values_Lappd[b:bE,0].reshape(-1,1,1,1)
    LAPPD2array = all_values_Lappd[b:bE,1].reshape(-1,1,1,1)
    LAPPD3array = all_values_Lappd[b:bE,2].reshape(-1,1,1,1)
    LAPPD4array = all_values_Lappd[b:bE,3].reshape(-1,1,1,1)
    LAPPD5array = all_values_Lappd[b:bE,4].reshape(-1,1,1,1)
    LAPPD6array = all_values_Lappd[b:bE,5].reshape(-1,1,1,1)
    LAPPD7array = all_values_Lappd[b:bE,6].reshape(-1,1,1,1)
    LAPPD8array = all_values_Lappd[b:bE,7].reshape(-1,1,1,1)
    LAPPD9array = all_values_Lappd[b:bE,8].reshape(-1,1,1,1)
    LAPPD10array = all_values_Lappd[b:bE,9].reshape(-1,1,1,1)
    LAPPD11array = all_values_Lappd[b:bE,10].reshape(-1,1,1,1)
    LAPPD12array = all_values_Lappd[b:bE,11].reshape(-1,1,1,1)
    LAPPD13array = all_values_Lappd[b:bE,12].reshape(-1,1,1,1)
    LAPPD14array = all_values_Lappd[b:bE,13].reshape(-1,1,1,1)
    LAPPD15array = all_values_Lappd[b:bE,14].reshape(-1,1,1,1)
    LAPPD16array = all_values_Lappd[b:bE,15].reshape(-1,1,1,1)
    LAPPD17array = all_values_Lappd[b:bE,16].reshape(-1,1,1,1)
    LAPPD18array = all_values_Lappd[b:bE,17].reshape(-1,1,1,1)
    LAPPD19array = all_values_Lappd[b:bE,18].reshape(-1,1,1,1)
    LAPPD20array = all_values_Lappd[b:bE,19].reshape(-1,1,1,1)
    LAPPD21array = all_values_Lappd[b:bE,20].reshape(-1,1,1,1)
    LAPPD22array = all_values_Lappd[b:bE,21].reshape(-1,1,1,1)
    LAPPD23array = all_values_Lappd[b:bE,22].reshape(-1,1,1,1)
    LAPPD24array = all_values_Lappd[b:bE,23].reshape(-1,1,1,1)

    LAPPD1array = np.flip(np.flip(LAPPD1array,2),1)
    LAPPD2array = np.flip(np.flip(LAPPD2array,2),1)
    LAPPD3array = np.flip(np.flip(LAPPD3array,2),1)
    LAPPD4array = np.flip(np.flip(LAPPD4array,2),1)
    LAPPD5array = np.flip(np.flip(LAPPD5array,2),1)
    LAPPD6array = np.flip(np.flip(LAPPD6array,2),1)
    LAPPD7array = np.flip(np.flip(LAPPD7array,2),1)
    LAPPD8array = np.flip(np.flip(LAPPD8array,2),1)
    LAPPD9array = np.flip(np.flip(LAPPD9array,2),1)
    LAPPD10array = np.flip(np.flip(LAPPD10array,2),1)
    LAPPD11array = np.flip(np.flip(LAPPD11array,2),1)
    LAPPD12array = np.flip(np.flip(LAPPD12array,2),1)
    LAPPD13array = np.flip(np.flip(LAPPD13array,2),1)
    LAPPD14array = np.flip(np.flip(LAPPD14array,2),1)
    LAPPD15array = np.flip(np.flip(LAPPD15array,2),1)
    LAPPD16array = np.flip(np.flip(LAPPD16array,2),1)
    LAPPD17array = np.flip(np.flip(LAPPD17array,2),1)
    LAPPD18array = np.flip(np.flip(LAPPD18array,2),1)
    LAPPD19array = np.flip(np.flip(LAPPD19array,2),1)
    LAPPD20array = np.flip(np.flip(LAPPD20array,2),1)
    LAPPD21array = np.flip(np.flip(LAPPD21array,2),1)
    LAPPD22array = np.flip(np.flip(LAPPD22array,2),1)
    LAPPD23array = np.flip(np.flip(LAPPD23array,2),1)
    LAPPD24array = np.flip(np.flip(LAPPD24array,2),1)
    
    a=len(LAPPD1array) 

    LP1=np.concatenate([LAPPD3array,LAPPD2array,LAPPD1array], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([LAPPD6array,LAPPD5array,LAPPD4array], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([LAPPD9array,LAPPD8array,LAPPD7array], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([LAPPD12array,LAPPD11array,LAPPD10array], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([LAPPD15array,LAPPD14array,LAPPD13array], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([LAPPD18array,LAPPD17array,LAPPD16array], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([LAPPD21array,LAPPD20array,LAPPD19array], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([LAPPD24array,LAPPD23array,LAPPD22array], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array

    del all_values_Lappd  
    #print("LAPPD Zyklus fertig: {}".format(i))
    
    

    
    
    
    fertigTime = np.concatenate([LP1,LP2,LP3,LP4,LP5,LP6,LP7,LP8],axis=2)
    del LP1,LP2,LP3,LP4,LP5,LP6,LP7,LP8
    
  
    
    
    print(fertigTime.shape)
    
    ###### Ture Value
    
    
    trueVal= np.load('BeamRingCounting/Temp/RingsTrueFalse.npy') 
    trueVal = np.array(trueVal)
    print(trueVal.shape)
    
    
    ###### Transform Image
    
    training_data=list(zip(fertig,fertigTime))
    
    
    training_data = np.array(training_data).reshape(-1,2,3,8)
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))
    
    
#### Safe Data ####
    pickle_out = open("BeamRingCounting/pickle/Final/X_RC_LAPPD(1x1)_110k_Files_gn_tf.pickle","wb")
    pickle.dump(training_data,pickle_out, protocol=4)
    pickle_out.close()


    pickle_out = open("BeamRingCounting/pickle/Final/Y_RC_LAPPD(1x1)_110k_Files_gn_tf.pickle","wb")
    pickle.dump(trueVal,pickle_out, protocol=4)
    pickle_out.close()

    print("Fertig mit Speichern von {}".format(i+1))
    
    #if (i ==0):
        #break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# (110544, 3, 8, 1)
# (110544, 3, 8, 1)
# (110544, 2)
# Fertig mit Speichern von 1

# %% [markdown]
# ## Plot

# %%
plt.imshow(training_data[7,:,:,1], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[7,:,:,1], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[7,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[7,:,:,0], cmap='viridis', interpolation='None')

# %% [markdown]
# # 3) PMT + LAPPD
# ### No empty rows and columns

# %% [markdown]
# Change / Check ALWAYS before execution:
#
# 1. LAPPDres  correct?
# 2. LAPPDres2  correct?
# 3. reshape(, , , )   correct? Use jupyters Search and Replace function!
# 5. PMT Norm   correct?
# 4. NAME of pickle-file  correct?

# %% [markdown]
# ### Explanation of variables
#
# LAPPDres = Is used to mark the end of an LAPPD Pannel. But is weirdly calculated:
#
#     -> LAPPD-Area = 9 + LAPPDres
#
#     for 3x3   = 9   is LAPPDres = 0
#     for 5x5   = 25  is LAPPDres = 16
#     for 10x10 = 100 is LAPPDres = 91
#
# batchsize = How many files are going to be saved in one pickle file.
#
#     b = Start of your Data
#     and
#     be is calculated through the batchsize and iteration
#
#
#
#
# LAPPDres2 = Resoultion (10 means 10x10 and 5 means 5x5)
#
# Fill and Zusatz are values to enable filling of rows and columns. Here, they should be Zero.

# %%
#LAPPDres=91 #LAPPD_area - 9 = res*res - 9 = LAPPDres # dh für 5x5 ist LPPDres=16, für 10x10 ist LAPPD gleich 91
LAPPDres2=1
PMTNorm = 100 


b=0
bE=0
#batchsize=20000 #batchsize=110441


Zusatz=0
Fill=0

for i in tqdm(range(1)):
    all_values_Lappd = np.load('BeamRingCounting/Temp/ChargeLAPPD.npy')
    batchsize=len(all_values_Lappd)
    
    bE=b+batchsize
    LAPPD1array = all_values_Lappd[b:bE,0].reshape(-1,1,1,1)
    LAPPD2array = all_values_Lappd[b:bE,1].reshape(-1,1,1,1)
    LAPPD3array = all_values_Lappd[b:bE,2].reshape(-1,1,1,1)
    LAPPD4array = all_values_Lappd[b:bE,3].reshape(-1,1,1,1)
    LAPPD5array = all_values_Lappd[b:bE,4].reshape(-1,1,1,1)
    LAPPD6array = all_values_Lappd[b:bE,5].reshape(-1,1,1,1)
    LAPPD7array = all_values_Lappd[b:bE,6].reshape(-1,1,1,1)
    LAPPD8array = all_values_Lappd[b:bE,7].reshape(-1,1,1,1)
    LAPPD9array = all_values_Lappd[b:bE,8].reshape(-1,1,1,1)
    LAPPD10array = all_values_Lappd[b:bE,9].reshape(-1,1,1,1)
    LAPPD11array = all_values_Lappd[b:bE,10].reshape(-1,1,1,1)
    LAPPD12array = all_values_Lappd[b:bE,11].reshape(-1,1,1,1)
    LAPPD13array = all_values_Lappd[b:bE,12].reshape(-1,1,1,1)
    LAPPD14array = all_values_Lappd[b:bE,13].reshape(-1,1,1,1)
    LAPPD15array = all_values_Lappd[b:bE,14].reshape(-1,1,1,1)
    LAPPD16array = all_values_Lappd[b:bE,15].reshape(-1,1,1,1)
    LAPPD17array = all_values_Lappd[b:bE,16].reshape(-1,1,1,1)
    LAPPD18array = all_values_Lappd[b:bE,17].reshape(-1,1,1,1)
    LAPPD19array = all_values_Lappd[b:bE,18].reshape(-1,1,1,1)
    LAPPD20array = all_values_Lappd[b:bE,19].reshape(-1,1,1,1)
    LAPPD21array = all_values_Lappd[b:bE,20].reshape(-1,1,1,1)
    LAPPD22array = all_values_Lappd[b:bE,21].reshape(-1,1,1,1)
    LAPPD23array = all_values_Lappd[b:bE,22].reshape(-1,1,1,1)
    LAPPD24array = all_values_Lappd[b:bE,23].reshape(-1,1,1,1)
    LAPPD1array = np.flip(np.flip(LAPPD1array,2),1)
    LAPPD2array = np.flip(np.flip(LAPPD2array,2),1)
    LAPPD3array = np.flip(np.flip(LAPPD3array,2),1)
    LAPPD4array = np.flip(np.flip(LAPPD4array,2),1)
    LAPPD5array = np.flip(np.flip(LAPPD5array,2),1)
    LAPPD6array = np.flip(np.flip(LAPPD6array,2),1)
    LAPPD7array = np.flip(np.flip(LAPPD7array,2),1)
    LAPPD8array = np.flip(np.flip(LAPPD8array,2),1)
    LAPPD9array = np.flip(np.flip(LAPPD9array,2),1)
    LAPPD10array = np.flip(np.flip(LAPPD10array,2),1)
    LAPPD11array = np.flip(np.flip(LAPPD11array,2),1)
    LAPPD12array = np.flip(np.flip(LAPPD12array,2),1)
    LAPPD13array = np.flip(np.flip(LAPPD13array,2),1)
    LAPPD14array = np.flip(np.flip(LAPPD14array,2),1)
    LAPPD15array = np.flip(np.flip(LAPPD15array,2),1)
    LAPPD16array = np.flip(np.flip(LAPPD16array,2),1)
    LAPPD17array = np.flip(np.flip(LAPPD17array,2),1)
    LAPPD18array = np.flip(np.flip(LAPPD18array,2),1)
    LAPPD19array = np.flip(np.flip(LAPPD19array,2),1)
    LAPPD20array = np.flip(np.flip(LAPPD20array,2),1)
    LAPPD21array = np.flip(np.flip(LAPPD21array,2),1)
    LAPPD22array = np.flip(np.flip(LAPPD22array,2),1)
    LAPPD23array = np.flip(np.flip(LAPPD23array,2),1)
    LAPPD24array = np.flip(np.flip(LAPPD24array,2),1)
    
    
    a=batchsize
    #a=len(LAPPD1array)
    
    

    
    FillüLappd3 = np.zeros((a,int(2*LAPPDres2),1*LAPPDres2,1))
    FillzwLAPPD= np.zeros((a,int(1*LAPPDres2),1*LAPPDres2,1))
    FillzwLAPPD1= np.zeros((a,1*LAPPDres2,1*LAPPDres2,1))
    FillunterLAPPD1=np.zeros((a,int(3*LAPPDres2),1*LAPPDres2,1))
    
    print(LAPPD1array.shape,FillüLappd3.shape,FillzwLAPPD.shape,FillunterLAPPD1.shape) 
    
    
    LP1=np.concatenate([FillüLappd3,LAPPD3array,FillzwLAPPD,LAPPD2array,FillzwLAPPD1,LAPPD1array,FillunterLAPPD1], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([FillüLappd3,LAPPD6array,FillzwLAPPD,LAPPD5array,FillzwLAPPD1,LAPPD4array,FillunterLAPPD1], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([FillüLappd3,LAPPD9array,FillzwLAPPD,LAPPD8array,FillzwLAPPD1,LAPPD7array,FillunterLAPPD1], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([FillüLappd3,LAPPD12array,FillzwLAPPD,LAPPD11array,FillzwLAPPD1,LAPPD10array,FillunterLAPPD1], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([FillüLappd3,LAPPD15array,FillzwLAPPD,LAPPD14array,FillzwLAPPD1,LAPPD13array,FillunterLAPPD1], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([FillüLappd3,LAPPD18array,FillzwLAPPD,LAPPD17array,FillzwLAPPD1,LAPPD16array,FillunterLAPPD1], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([FillüLappd3,LAPPD21array,FillzwLAPPD,LAPPD20array,FillzwLAPPD1,LAPPD19array,FillunterLAPPD1], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([FillüLappd3,LAPPD24array,FillzwLAPPD,LAPPD23array,FillzwLAPPD1,LAPPD22array,FillunterLAPPD1], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array
    del all_values_Lappd  
    
    

    
    
    all_values = np.load('BeamRingCounting/Temp/ChargePMT.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    a=len(all_values)
    for event in range(b, bE):
        for x in range(160):
            
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres2,LAPPDres2))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres2,LAPPDres2,1))

    
    

    FillziwschenPMTs = np.zeros((a,0,1*LAPPDres2,1))
    
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
    print(LP1.shape, block1.shape)
    
    
    fertig=np.concatenate([LP1,block1],axis=2)
    del LP1,block1
    fertig=np.concatenate([fertig,block2,LP2],axis=2)
    del block2,LP2
    fertig=np.concatenate([fertig,block3,block4],axis=2)
    del block3,block4
    fertig=np.concatenate([fertig,LP3,block5],axis=2)
    del LP3,block5
    fertig=np.concatenate([fertig,block6,LP4],axis=2)
    del block6, LP4
    fertig=np.concatenate([fertig,block7,block8],axis=2)
    del block7,block8
    fertig=np.concatenate([fertig,LP5,block9],axis=2)
    del LP5,block9
    fertig=np.concatenate([fertig,block10,LP6],axis=2)
    del block10,LP6
    fertig=np.concatenate([fertig,block11,block12],axis=2)
    del block11,block12
    fertig=np.concatenate([fertig,LP7,block13],axis=2)
    del LP7, block13
    fertig=np.concatenate([fertig,block14,LP8],axis=2)
    del block14,LP8
    fertig=np.concatenate([fertig,block15],axis=2)
    del block15
    fertigC=np.concatenate([fertig,block16],axis=2)
    del block16
    #print(fertig.shape)
    #print("BigMapCharge Zyklus fertig: {}".format(i))

    plt.imshow(fertigC[7,:,:,0], cmap='viridis', interpolation='None')
    plt.show()
    ############################################### TIME #################################
    
    
    all_values_Lappd = np.load('BeamRingCounting/Temp/TimeLAPPD_flipped.npy')
    
    
    
    
    LAPPD1array = all_values_Lappd[b:bE,0].reshape(-1,1,1,1)
    LAPPD2array = all_values_Lappd[b:bE,1].reshape(-1,1,1,1)
    LAPPD3array = all_values_Lappd[b:bE,2].reshape(-1,1,1,1)
    LAPPD4array = all_values_Lappd[b:bE,3].reshape(-1,1,1,1)
    LAPPD5array = all_values_Lappd[b:bE,4].reshape(-1,1,1,1)
    LAPPD6array = all_values_Lappd[b:bE,5].reshape(-1,1,1,1)
    LAPPD7array = all_values_Lappd[b:bE,6].reshape(-1,1,1,1)
    LAPPD8array = all_values_Lappd[b:bE,7].reshape(-1,1,1,1)
    LAPPD9array = all_values_Lappd[b:bE,8].reshape(-1,1,1,1)
    LAPPD10array = all_values_Lappd[b:bE,9].reshape(-1,1,1,1)
    LAPPD11array = all_values_Lappd[b:bE,10].reshape(-1,1,1,1)
    LAPPD12array = all_values_Lappd[b:bE,11].reshape(-1,1,1,1)
    LAPPD13array = all_values_Lappd[b:bE,12].reshape(-1,1,1,1)
    LAPPD14array = all_values_Lappd[b:bE,13].reshape(-1,1,1,1)
    LAPPD15array = all_values_Lappd[b:bE,14].reshape(-1,1,1,1)
    LAPPD16array = all_values_Lappd[b:bE,15].reshape(-1,1,1,1)
    LAPPD17array = all_values_Lappd[b:bE,16].reshape(-1,1,1,1)
    LAPPD18array = all_values_Lappd[b:bE,17].reshape(-1,1,1,1)
    LAPPD19array = all_values_Lappd[b:bE,18].reshape(-1,1,1,1)
    LAPPD20array = all_values_Lappd[b:bE,19].reshape(-1,1,1,1)
    LAPPD21array = all_values_Lappd[b:bE,20].reshape(-1,1,1,1)
    LAPPD22array = all_values_Lappd[b:bE,21].reshape(-1,1,1,1)
    LAPPD23array = all_values_Lappd[b:bE,22].reshape(-1,1,1,1)
    LAPPD24array = all_values_Lappd[b:bE,23].reshape(-1,1,1,1)
    LAPPD1array = np.flip(np.flip(LAPPD1array,2),1)
    LAPPD2array = np.flip(np.flip(LAPPD2array,2),1)
    LAPPD3array = np.flip(np.flip(LAPPD3array,2),1)
    LAPPD4array = np.flip(np.flip(LAPPD4array,2),1)
    LAPPD5array = np.flip(np.flip(LAPPD5array,2),1)
    LAPPD6array = np.flip(np.flip(LAPPD6array,2),1)
    LAPPD7array = np.flip(np.flip(LAPPD7array,2),1)
    LAPPD8array = np.flip(np.flip(LAPPD8array,2),1)
    LAPPD9array = np.flip(np.flip(LAPPD9array,2),1)
    LAPPD10array = np.flip(np.flip(LAPPD10array,2),1)
    LAPPD11array = np.flip(np.flip(LAPPD11array,2),1)
    LAPPD12array = np.flip(np.flip(LAPPD12array,2),1)
    LAPPD13array = np.flip(np.flip(LAPPD13array,2),1)
    LAPPD14array = np.flip(np.flip(LAPPD14array,2),1)
    LAPPD15array = np.flip(np.flip(LAPPD15array,2),1)
    LAPPD16array = np.flip(np.flip(LAPPD16array,2),1)
    LAPPD17array = np.flip(np.flip(LAPPD17array,2),1)
    LAPPD18array = np.flip(np.flip(LAPPD18array,2),1)
    LAPPD19array = np.flip(np.flip(LAPPD19array,2),1)
    LAPPD20array = np.flip(np.flip(LAPPD20array,2),1)
    LAPPD21array = np.flip(np.flip(LAPPD21array,2),1)
    LAPPD22array = np.flip(np.flip(LAPPD22array,2),1)
    LAPPD23array = np.flip(np.flip(LAPPD23array,2),1)
    LAPPD24array = np.flip(np.flip(LAPPD24array,2),1)
    
    a=batchsize
    #a=len(LAPPD1array)
    
    

    
    
    FillüLappd3 = np.zeros((a,int(2*LAPPDres2),1*LAPPDres2,1))
    FillzwLAPPD= np.zeros((a,int(1*LAPPDres2),1*LAPPDres2,1))
    FillzwLAPPD1= np.zeros((a,LAPPDres2,1*LAPPDres2,1))
    FillunterLAPPD1=np.zeros((a,int(3*LAPPDres2),1*LAPPDres2,1))
    
    print(LAPPD1array.shape,FillüLappd3.shape,FillzwLAPPD.shape,FillunterLAPPD1.shape) 
    
    
    LP1=np.concatenate([FillüLappd3,LAPPD3array,FillzwLAPPD,LAPPD2array,FillzwLAPPD1,LAPPD1array,FillunterLAPPD1], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([FillüLappd3,LAPPD6array,FillzwLAPPD,LAPPD5array,FillzwLAPPD1,LAPPD4array,FillunterLAPPD1], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([FillüLappd3,LAPPD9array,FillzwLAPPD,LAPPD8array,FillzwLAPPD1,LAPPD7array,FillunterLAPPD1], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([FillüLappd3,LAPPD12array,FillzwLAPPD,LAPPD11array,FillzwLAPPD1,LAPPD10array,FillunterLAPPD1], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([FillüLappd3,LAPPD15array,FillzwLAPPD,LAPPD14array,FillzwLAPPD1,LAPPD13array,FillunterLAPPD1], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([FillüLappd3,LAPPD18array,FillzwLAPPD,LAPPD17array,FillzwLAPPD1,LAPPD16array,FillunterLAPPD1], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([FillüLappd3,LAPPD21array,FillzwLAPPD,LAPPD20array,FillzwLAPPD1,LAPPD19array,FillunterLAPPD1], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([FillüLappd3,LAPPD24array,FillzwLAPPD,LAPPD23array,FillzwLAPPD1,LAPPD22array,FillunterLAPPD1], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array

    del all_values_Lappd  
    
    
    
    
    all_values = np.load('BeamRingCounting/Temp/TimePMT_flipped.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    a=batchsize#len(all_values)

    
    
    for event in range(b, bE):
        for x in range(160):
            
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres2,LAPPDres2))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres2,LAPPDres2,1))

    
    


    FillziwschenPMTs = np.zeros((a,Zusatz*Fill*0,1*LAPPDres2,1))
    print(val[:,143+1].shape,FillziwschenPMTs.shape)
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
  
    FillRow = np.zeros((a,len(block1[0]),Fill*LAPPDres2,1))
    
    print(LP1.shape, block1.shape)
    
    
    fertig=np.concatenate([LP1,block1],axis=2)
    del LP1,block1
    fertig=np.concatenate([fertig,block2,LP2],axis=2)
    del block2,LP2
    fertig=np.concatenate([fertig,block3,block4],axis=2)
    del block3,block4
    fertig=np.concatenate([fertig,LP3,block5],axis=2)
    del LP3,block5
    fertig=np.concatenate([fertig,block6,LP4],axis=2)
    del block6, LP4
    fertig=np.concatenate([fertig,block7,block8],axis=2)
    del block7,block8
    fertig=np.concatenate([fertig,LP5,block9],axis=2)
    del LP5,block9
    fertig=np.concatenate([fertig,block10,LP6],axis=2)
    del block10,LP6
    fertig=np.concatenate([fertig,block11,block12],axis=2)
    del block11,block12
    fertig=np.concatenate([fertig,LP7,block13],axis=2)
    del LP7, block13
    fertig=np.concatenate([fertig,block14,LP8],axis=2)
    del block14,LP8
    fertig=np.concatenate([fertig,block15],axis=2)
    del block15
    fertigTime=np.concatenate([fertig,block16],axis=2)
    del block16
    #print(fertig.shape)
    #print("BigMapCharge Zyklus fertig: {}".format(i))

    plt.imshow(fertigTime[7,:,:,0], cmap='viridis', interpolation='None')
    plt.show()
    
    trueVal= np.load('BeamRingCounting/Temp/RingsTrueFalse.npy')
    print(fertigC.shape,fertigTime.shape)
    
    trueVal = np.array(trueVal[b:bE])
    
    
    
    training_data=list(zip(fertigC,fertigTime))
    preX1 =[]
    preX2 =[]

    for x in training_data:
        #preX1A = np.array([x[0]]).reshape(-1, 20,16, 1)
        preX1.append(x[0])
    #    preX2A = np.array([x[1]]).reshape(-1, 20,16, 1)
        preX2.append(x[1])


    training_data = list(zip(preX1, preX2))
    
    training_data = np.array(training_data)
    
    print(training_data.shape)
    training_data = training_data.reshape(-1, 2, training_data.shape[2],training_data.shape[3])
    print(training_data.shape)
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))
    print(training_data.shape)

    

    #print("Shape ist: ", training_data.shape)
    trueValu=trueVal[b:bE]

    
    pickle_out = open("BeamRingCounting/pickle/Final/X_RC_PMT+LAPPD(1x1)_110k_Files_gn_tf.pickle","wb")
    pickle.dump(training_data,pickle_out,protocol=4)
    pickle_out.close()


    pickle_out = open("BeamRingCounting/pickle/Final/Y_RC_PMT+LAPPD(1x1)_110k_Files_gn_tf.pickle","wb")
    pickle.dump(trueVal,pickle_out,protocol=4)
    pickle_out.close()

    #np.save('BeamlikeRingCounting/X_BeamlikeLappd_110k_Lappd1x1')
    #np.save('BeamlikeRingCounting/Y_BeamlikeLappd_110k_Lappd1x1')
    print("Fertig mit Speichern von {}".format(i))
    
    #if (i ==0):
        #break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# (110544, 1, 1, 1) (110544, 2, 1, 1) (110544, 1, 1, 1) (110544, 3, 1, 1)
# (110544, 10, 1, 1) (110544, 10, 1, 1)
# (110544, 1, 1, 1) (110544, 2, 1, 1) (110544, 1, 1, 1) (110544, 3, 1, 1)
# (110544, 1, 1, 1) (110544, 0, 1, 1)
# (110544, 10, 1, 1) (110544, 10, 1, 1)
# (110544, 10, 24, 1) (110544, 10, 24, 1)
# (110544, 2, 10, 24, 1)
# (110544, 2, 10, 24)
# (110544, 10, 24, 2)
# Fertig mit Speichern von 0

# %%
plt.imshow(training_data[7,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[7
                         
                         
                         ,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[30,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[10,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[10,:,:,0], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[10,:,:,0], cmap='viridis', interpolation='None')

# %% [markdown]
# ## PMT (mit Top und Bottom) ONLY

# %% [markdown]
# Ohne fill

# %%
b=0
LAPPDres=1
bE=0
batchsize=110544
for i in tqdm(range(1)):
    bE=bE+batchsize
   
    
    

    
    
    
    all_values = np.load('BeamRingCounting/Temp/ChargePMT.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    a=len(all_values)
    for event in range(b, bE):
        for x in range(160):
            
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres,LAPPDres))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres,LAPPDres,1))

    
    

    FillziwschenPMTs = np.zeros((a,0,1*LAPPDres,1))
    
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
  
    
    
    fertigC=np.concatenate([block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16],axis=2)
    del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
  

    
    ############################################### TIME #################################
    
   
    all_values = np.load('BeamRingCounting/Temp/TimePMT_flipped.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    
    for event in range(b, bE):
        for x in range(160):
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres,LAPPDres))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres,LAPPDres,1))

    
    

    FillziwschenPMTs = np.zeros((a,0,1*LAPPDres,1))
    
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
    fertigT=np.concatenate([block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16],axis=2)
    del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
  
    


    
    
    trueVal= np.load('BeamRingCounting/Temp/RingsTrueFalse.npy')
    print(fertig.shape)
    
    trueVal = np.array(trueVal)
    
    
    
    training_data=list(zip(fertigC,fertigT))
    preX1 =[]
    preX2 =[]

    for x in training_data:
        #preX1A = np.array([x[0]]).reshape(-1, 20,16, 1)
        preX1.append(x[0])
    #    preX2A = np.array([x[1]]).reshape(-1, 20,16, 1)
        preX2.append(x[1])


    training_data = list(zip(preX1, preX2))
    
    training_data = np.array(training_data)
    
    print(training_data.shape)
    training_data = training_data.reshape(-1, 2, 10*LAPPDres,16*LAPPDres)
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))


    

    #print("Shape ist: ", training_data.shape)
    trueValu=trueVal[b:bE]
    pickle_out = open("BeamRingCounting/pickle/Final/X_RC_PMT_110k_Files_gn_tf.pickle","wb")
    pickle.dump(training_data,pickle_out)
    pickle_out.close()


    pickle_out = open("BeamRingCounting/pickle/Final/Y_RC_PMT_110k_Files_gn_tf.pickle","wb")
    pickle.dump(trueVal,pickle_out)
    pickle_out.close()

    #np.save('BeamlikeRingCounting/X_BeamlikeLappd_110k_Lappd1x1')
    #np.save('BeamlikeRingCounting/Y_BeamlikeLappd_110k_Lappd1x1')
    print("Fertig mit Speichern von {}".format(i))
    
    #if (i ==0):
        #break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# (110544, 10, 23, 1)
# (110544, 2, 10, 16, 1)
# Fertig mit Speichern von 0

# %%
plt.imshow(training_data[7,:,:,1], cmap='viridis', interpolation='None')

# %%
plt.imshow(training_data[7,:,:,0], cmap='viridis', interpolation='None')

# %% [markdown]
# ## PMT (mit Top und Bottom) Nur 24 PMTs

# %%
b=0
LAPPDres=1
bE=0

for i in tqdm(range(1)):
    bE=bE+batchsize
   
    
    

    
    
    
    all_values = np.load('BeamRingCounting/Temp/ChargePMT.npy')
    batchsize=len(all_values)
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    a=len(all_values)
    for event in range(b, bE):
        for x in range(160):
            
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres,LAPPDres))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres,LAPPDres,1))

    
    

    FillziwschenPMTs = np.zeros((a,0,1*LAPPDres,1))
    
    block1=np.concatenate([val[:,80+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,16+32]],axis=1) #1
    #block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,82+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,18+32]],axis=1) #2
    #block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,84+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,20+32]],axis=1) #3
    #block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,86+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,22+32]],axis=1) #4
    #block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,88+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,24+32]],axis=1) #5
    #block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,90+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,26+32]],axis=1) #6
    #block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,92+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,28+32]],axis=1) #7
   # block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,94+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,30+32]],axis=1) #8
    #block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
  
    
    
    fertigC=np.concatenate([block1,block3,block5,block7,block9,block11,block13,block15],axis=2)
   # del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
    del block1,block3,block5,block7,block9,block11,block13,block15

    print("FertigC")
    ############################################### TIME #################################
    
   
    all_values = np.load('BeamRingCounting/Temp/TimePMT_flipped.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    
    for event in range(b, bE):
        for x in range(160):
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres,LAPPDres))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres2,LAPPDres2,1))

    
    

    FillziwschenPMTs = np.zeros((a,0,1*LAPPDres2,1))
    
    block1=np.concatenate([val[:,80+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,16+32]],axis=1) #1
    #block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,82+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,18+32]],axis=1) #2
    #block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,84+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,20+32]],axis=1) #3
    #block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,86+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,22+32]],axis=1) #4
    #block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,88+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,24+32]],axis=1) #5
    #block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,90+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,26+32]],axis=1) #6
    #block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,92+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,28+32]],axis=1) #7
   # block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,94+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,30+32]],axis=1) #8
    #block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
  
    
    
    fertigT=np.concatenate([block1,block3,block5,block7,block9,block11,block13,block15],axis=2)
   # del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
    del block1,block3,block5,block7,block9,block11,block13,block15


    
    
    trueVal= np.load('BeamRingCounting/Temp/RingsTrueFalse.npy')
    
    
    trueVal = np.array(trueVal)
    
    
    
    training_data=list(zip(fertigC,fertigT))
    preX1 =[]
    preX2 =[]

    for x in training_data:
        #preX1A = np.array([x[0]]).reshape(-1, 20,16, 1)
        preX1.append(x[0])
    #    preX2A = np.array([x[1]]).reshape(-1, 20,16, 1)
        preX2.append(x[1])


    training_data = list(zip(preX1, preX2))
    
    training_data = np.array(training_data)
    
    print(training_data.shape)
    training_data = training_data.reshape(-1, 2, 3*LAPPDres2,8*LAPPDres2)
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))


    

    #print("Shape ist: ", training_data.shape)
    trueValu=trueVal[b:bE]
    import pickle

    pickle_out = open("BeamRingCounting/pickle/Final/X_RC_24PMTs_110k_Files_gn_tf.pickle","wb")
    pickle.dump(training_data,pickle_out)
    pickle_out.close()


    pickle_out = open("BeamRingCounting/pickle/Final/Y_RC_24PMTs_110k_Files_gn_tf.pickle","wb")
    pickle.dump(trueVal,pickle_out)
    pickle_out.close()

    #np.save('BeamlikeRingCounting/X_BeamlikeLappd_110k_Lappd1x1')
    #np.save('BeamlikeRingCounting/Y_BeamlikeLappd_110k_Lappd1x1')
    print("Fertig mit Speichern von {}".format(i))
    
    #if (i ==0):
        #break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# FertigC
# (110544, 2, 3, 8, 1)
# Fertig mit Speichern von 0

# %%
plt.imshow(training_data[7,:,:,0], cmap='viridis', interpolation='None')

# %% [markdown]
# # PMT (Top and Bottom) Only
#
# with Fill

# %%
b=0
LAPPDres2=10
bE=0
batchsize=23552
Fill= 1
Zusatz=0  # Zusatz=1 bedeutet die Spalten werden aufgestockt Zusatz = 0 bedeutet es gibt keine Leeren Einträge in PMT Spalten
for i in tqdm(range(1)):
    bE=bE+batchsize
   
    
    

    
    
    
    all_values = np.load('BeamlikePI/Temp/ChargePMT.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    a=len(all_values)

    
    
    for event in range(b, bE):
        for x in range(160):
            
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres2,LAPPDres2))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres2,LAPPDres2,1))

    
    

    FillziwschenPMTs = np.zeros((a,Zusatz*Fill*LAPPDres2,1*LAPPDres2,1))
    
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
  
    FillRow = np.zeros((a,len(block1[0]),Fill*LAPPDres2,1))
    print(FillRow.shape, block1.shape)
    fertigC=np.concatenate([FillRow,block1,FillRow,block2,FillRow,block3,FillRow,block4,FillRow,block5,FillRow,block6,FillRow,block7,FillRow,block8,FillRow,block9,FillRow,block10,FillRow,block11,FillRow,block12,FillRow,block13,FillRow,block14,FillRow,block15,FillRow,block16],axis=2)
    del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
  


    ############################################### TIME #################################
    
   
    all_values = np.load('BeamlikePI/Temp/TimePMT.npy')
    
    PMT_array = defaultdict(dict)
    val=[]
    

    
    
    for event in range(b, bE):
        for x in range(160):
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((LAPPDres2,LAPPDres2))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,160,LAPPDres2,LAPPDres2,1))

    
    

    FillziwschenPMTs = np.zeros((a,Zusatz*Fill*LAPPDres2,1*LAPPDres2,1))
    
    block1=np.concatenate([val[:,143+1],FillziwschenPMTs,val[:,127+1],FillziwschenPMTs,val[:,80+32],FillziwschenPMTs,val[:,64+32],FillziwschenPMTs,val[:,48+32],FillziwschenPMTs,val[:,32+32],FillziwschenPMTs,val[:,16+32],FillziwschenPMTs,val[:,0+32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0]],axis=1)
    block2=np.concatenate([val[:,144+1],FillziwschenPMTs,val[:,128+1],FillziwschenPMTs,val[:,81+32],FillziwschenPMTs,val[:,65+32],FillziwschenPMTs,val[:,49+32],FillziwschenPMTs,val[:,33+32],FillziwschenPMTs,val[:,17+32],FillziwschenPMTs,val[:,1+32],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1]],axis=1)
    block3=np.concatenate([val[:,145+1],FillziwschenPMTs,val[:,129+1],FillziwschenPMTs,val[:,82+32],FillziwschenPMTs,val[:,66+32],FillziwschenPMTs,val[:,50+32],FillziwschenPMTs,val[:,34+32],FillziwschenPMTs,val[:,18+32],FillziwschenPMTs,val[:,2+32],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2]],axis=1)
    block4=np.concatenate([val[:,146+1],FillziwschenPMTs,val[:,130+1],FillziwschenPMTs,val[:,83+32],FillziwschenPMTs,val[:,67+32],FillziwschenPMTs,val[:,51+32],FillziwschenPMTs,val[:,35+32],FillziwschenPMTs,val[:,19+32],FillziwschenPMTs,val[:,3+32],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3]],axis=1)
    block5=np.concatenate([val[:,147+1],FillziwschenPMTs,val[:,131+1],FillziwschenPMTs,val[:,84+32],FillziwschenPMTs,val[:,68+32],FillziwschenPMTs,val[:,52+32],FillziwschenPMTs,val[:,36+32],FillziwschenPMTs,val[:,20+32],FillziwschenPMTs,val[:,4+32],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4]],axis=1)
    block6=np.concatenate([val[:,148+1],FillziwschenPMTs,val[:,132+1],FillziwschenPMTs,val[:,85+32],FillziwschenPMTs,val[:,69+32],FillziwschenPMTs,val[:,53+32],FillziwschenPMTs,val[:,37+32],FillziwschenPMTs,val[:,21+32],FillziwschenPMTs,val[:,5+32],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5]],axis=1)
    block7=np.concatenate([val[:,149+1],FillziwschenPMTs,val[:,133+1],FillziwschenPMTs,val[:,86+32],FillziwschenPMTs,val[:,70+32],FillziwschenPMTs,val[:,54+32],FillziwschenPMTs,val[:,38+32],FillziwschenPMTs,val[:,22+32],FillziwschenPMTs,val[:,6+32],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6]],axis=1)
    block8=np.concatenate([val[:,150+1],FillziwschenPMTs,val[:,134+1],FillziwschenPMTs,val[:,87+32],FillziwschenPMTs,val[:,71+32],FillziwschenPMTs,val[:,55+32],FillziwschenPMTs,val[:,39+32],FillziwschenPMTs,val[:,23+32],FillziwschenPMTs,val[:,7+32],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7]],axis=1)
    block9=np.concatenate([val[:,151+1],FillziwschenPMTs,val[:,135+1],FillziwschenPMTs,val[:,88+32],FillziwschenPMTs,val[:,72+32],FillziwschenPMTs,val[:,56+32],FillziwschenPMTs,val[:,40+32],FillziwschenPMTs,val[:,24+32],FillziwschenPMTs,val[:,8+32],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8]],axis=1)
    block10=np.concatenate([val[:,152+1],FillziwschenPMTs,val[:,136+1],FillziwschenPMTs,val[:,89+32],FillziwschenPMTs,val[:,73+32],FillziwschenPMTs,val[:,57+32],FillziwschenPMTs,val[:,41+32],FillziwschenPMTs,val[:,25+32],FillziwschenPMTs,val[:,9+32],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9]],axis=1)
    block11=np.concatenate([val[:,153+1],FillziwschenPMTs,val[:,137+1],FillziwschenPMTs,val[:,90+32],FillziwschenPMTs,val[:,74+32],FillziwschenPMTs,val[:,58+32],FillziwschenPMTs,val[:,42+32],FillziwschenPMTs,val[:,26+32],FillziwschenPMTs,val[:,10+32],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10]],axis=1)
    block12=np.concatenate([val[:,154+1],FillziwschenPMTs,val[:,138+1],FillziwschenPMTs,val[:,91+32],FillziwschenPMTs,val[:,75+32],FillziwschenPMTs,val[:,59+32],FillziwschenPMTs,val[:,43+32],FillziwschenPMTs,val[:,27+32],FillziwschenPMTs,val[:,11+32],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11]],axis=1)
    block13=np.concatenate([val[:,155+1],FillziwschenPMTs,val[:,139+1],FillziwschenPMTs,val[:,92+32],FillziwschenPMTs,val[:,76+32],FillziwschenPMTs,val[:,60+32],FillziwschenPMTs,val[:,44+32],FillziwschenPMTs,val[:,28+32],FillziwschenPMTs,val[:,12+32],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12]],axis=1)
    block14=np.concatenate([val[:,156+1],FillziwschenPMTs,val[:,140+1],FillziwschenPMTs,val[:,93+32],FillziwschenPMTs,val[:,77+32],FillziwschenPMTs,val[:,61+32],FillziwschenPMTs,val[:,45+32],FillziwschenPMTs,val[:,29+32],FillziwschenPMTs,val[:,13+32],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13]],axis=1)
    block15=np.concatenate([val[:,157+1],FillziwschenPMTs,val[:,141+1],FillziwschenPMTs,val[:,94+32],FillziwschenPMTs,val[:,78+32],FillziwschenPMTs,val[:,62+32],FillziwschenPMTs,val[:,46+32],FillziwschenPMTs,val[:,30+32],FillziwschenPMTs,val[:,14+32],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14]],axis=1)
    block16=np.concatenate([val[:,158+1],FillziwschenPMTs,val[:,142+1],FillziwschenPMTs,val[:,95+32],FillziwschenPMTs,val[:,79+32],FillziwschenPMTs,val[:,63+32],FillziwschenPMTs,val[:,47+32],FillziwschenPMTs,val[:,31+32],FillziwschenPMTs,val[:,15+32],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15]],axis=1)
    del val
    
    
    FillRow = np.zeros((a,len(block1[0]),Fill*LAPPDres2,1))
    print(FillRow.shape, block1.shape)
    fertigT=np.concatenate([FillRow,block1,FillRow,block2,FillRow,block3,FillRow,block4,FillRow,block5,FillRow,block6,FillRow,block7,FillRow,block8,FillRow,block9,FillRow,block10,FillRow,block11,FillRow,block12,FillRow,block13,FillRow,block14,FillRow,block15,FillRow,block16],axis=2)
    del block1,block2,block3,block4,block5,block6,block7,block8,block9,block10,block11,block12,block13,block14,block15,block16
  
    


    
    
    trueVal= np.load('BeamlikePI/Temp/category_values.npy')
    
    
    trueVal = np.array(trueVal)
    
    
    
    training_data=list(zip(fertigC,fertigT))
    preX1 =[]
    preX2 =[]

    for x in training_data:
        #preX1A = np.array([x[0]]).reshape(-1, 20,16, 1)
        preX1.append(x[0])
    #    preX2A = np.array([x[1]]).reshape(-1, 20,16, 1)
        preX2.append(x[1])


    training_data = list(zip(preX1, preX2))
    
    training_data = np.array(training_data)
    
    print(training_data.shape)
    training_data = training_data.reshape(-1, 2, training_data.shape[2],training_data.shape[3])
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))


    

    #print("Shape ist: ", training_data.shape)
    trueValu=trueVal[b:bE]
    import pickle

    pickle_out = open("BeamlikePI/pickle/X_Beamlike_PI_20x20_PMT_160_Only_20k_Files_mitTopBottom_mitFill.pickle","wb")
    pickle.dump(training_data,pickle_out,protocol=4)
    pickle_out.close()


    pickle_out = open("BeamlikePI/pickle/Y_Beamlike_PI_20x20_PMT_160_Only_20k_Files_mitTopBottom_mitFill.pickle","wb")
    pickle.dump(trueVal,pickle_out,protocol=4)
    pickle_out.close()

    #np.save('BeamlikeRingCounting/X_BeamlikeLappd_110k_Lappd1x1')
    #np.save('BeamlikeRingCounting/Y_BeamlikeLappd_110k_Lappd1x1')
    print("Fertig mit Speichern von {}".format(i))
    
    #if (i ==0):
        #break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# (23552, 100, 10, 1) (23552, 100, 10, 1)
# (23552, 100, 10, 1) (23552, 100, 10, 1)
# (23552, 2, 100, 320, 1)
# Fertig mit Speichern von 0

# %%
plt.imshow(training_data[6,:,:,0], cmap='viridis', interpolation='None')

# %% [markdown]
# # Single Files

# %%
b=0
files=32955
bE=0
batchsize=1
for i in tqdm(range(files)):
    
    
    all_values_Lappd = np.load('Temp/ChargeLAPPD.npy')
    
    
    bE=bE+batchsize
    LAPPD1array = all_values_Lappd[b:bE,0:400].reshape(-1,20,20,1)
    LAPPD2array = all_values_Lappd[b:bE,400:800].reshape(-1,20,20,1)
    LAPPD3array = all_values_Lappd[b:bE,800:1200].reshape(-1,20,20,1)
    LAPPD4array = all_values_Lappd[b:bE,1199+1:1599+1].reshape(-1,20,20,1)
    LAPPD5array = all_values_Lappd[b:bE,1599+1:1999+1].reshape(-1,20,20,1)
    LAPPD6array = all_values_Lappd[b:bE,1999+1:2399+1].reshape(-1,20,20,1)
    LAPPD7array = all_values_Lappd[b:bE,2399+1:2799+1].reshape(-1,20,20,1)
    LAPPD8array = all_values_Lappd[b:bE,2799+1:3199+1].reshape(-1,20,20,1)
    LAPPD9array = all_values_Lappd[b:bE,3199+1:3599+1].reshape(-1,20,20,1)
    LAPPD10array = all_values_Lappd[b:bE,3599+1:3999+1].reshape(-1,20,20,1)
    LAPPD11array = all_values_Lappd[b:bE,3999+1:4399+1].reshape(-1,20,20,1)
    LAPPD12array = all_values_Lappd[b:bE,4399+1:4799+1].reshape(-1,20,20,1)
    LAPPD13array = all_values_Lappd[b:bE,4799+1:5199+1].reshape(-1,20,20,1)
    LAPPD14array = all_values_Lappd[b:bE,5199+1:5599+1].reshape(-1,20,20,1)
    LAPPD15array = all_values_Lappd[b:bE,5599+1:5999+1].reshape(-1,20,20,1)
    LAPPD16array = all_values_Lappd[b:bE,5999+1:6399+1].reshape(-1,20,20,1)
    LAPPD17array = all_values_Lappd[b:bE,6400:6799+1].reshape(-1,20,20,1)
    LAPPD18array = all_values_Lappd[b:bE,6800:7199+1].reshape(-1,20,20,1)
    LAPPD19array = all_values_Lappd[b:bE,7200:7599+1].reshape(-1,20,20,1)
    LAPPD20array = all_values_Lappd[b:bE,7600:7999+1].reshape(-1,20,20,1)
    LAPPD21array = all_values_Lappd[b:bE,8000:8399+1].reshape(-1,20,20,1)
    LAPPD22array = all_values_Lappd[b:bE,8400:8799+1].reshape(-1,20,20,1)
    LAPPD23array = all_values_Lappd[b:bE,8800:9199+1].reshape(-1,20,20,1)
    LAPPD24array = all_values_Lappd[b:bE,9200:9599+1].reshape(-1,20,20,1)

    
    a=len(LAPPD1array)
    FillüLappd3 = np.zeros((a,51,20,1))
    FillzwLAPPD= np.zeros((a,22,20,1))
    FillunterLAPPD1=np.zeros((a,54,20,1))


    LP1=np.concatenate([FillüLappd3,LAPPD3array,FillzwLAPPD,LAPPD2array,FillzwLAPPD,LAPPD1array,FillunterLAPPD1], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([FillüLappd3,LAPPD6array,FillzwLAPPD,LAPPD5array,FillzwLAPPD,LAPPD4array,FillunterLAPPD1], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([FillüLappd3,LAPPD9array,FillzwLAPPD,LAPPD8array,FillzwLAPPD,LAPPD7array,FillunterLAPPD1], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([FillüLappd3,LAPPD12array,FillzwLAPPD,LAPPD11array,FillzwLAPPD,LAPPD10array,FillunterLAPPD1], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([FillüLappd3,LAPPD15array,FillzwLAPPD,LAPPD14array,FillzwLAPPD,LAPPD13array,FillunterLAPPD1], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([FillüLappd3,LAPPD18array,FillzwLAPPD,LAPPD17array,FillzwLAPPD,LAPPD16array,FillunterLAPPD1], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([FillüLappd3,LAPPD21array,FillzwLAPPD,LAPPD20array,FillzwLAPPD,LAPPD19array,FillunterLAPPD1], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([FillüLappd3,LAPPD24array,FillzwLAPPD,LAPPD23array,FillzwLAPPD,LAPPD22array,FillunterLAPPD1], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array

    del all_values_Lappd  
    #print("LAPPD Zyklus fertig: {}".format(i))
    
    
    
    all_values = np.load('Temp/ChargePMT.npy')
    PMT_array = defaultdict(dict)
    val=[]
    

    
    
    for event in range(b, bE):
        for x in range(0, 96):
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((20,20))
            
        val.append(list(PMT_array[event].values()))
    
    del PMT_array , all_values  

    
    val= np.array(val,dtype = np.float).reshape((-1,96,20,20,1))

    
    

    FillüberundunterPMT = np.zeros((a,42,20,1))
    FillziwschenPMTs = np.zeros((a,1,20,1))
    nullerspalte=np.zeros((a,209,1,1))
    
    

    
    
    block1=np.concatenate([FillüberundunterPMT,val[:,80],FillziwschenPMTs,val[:,64],FillziwschenPMTs,val[:,48],FillziwschenPMTs,val[:,32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0],FillüberundunterPMT],axis=1)
    block2=np.concatenate([FillüberundunterPMT,val[:,81],FillziwschenPMTs,val[:,65],FillziwschenPMTs,val[:,49],FillziwschenPMTs,val[:,33],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1],FillüberundunterPMT],axis=1)
    block3=np.concatenate([FillüberundunterPMT,val[:,82],FillziwschenPMTs,val[:,66],FillziwschenPMTs,val[:,50],FillziwschenPMTs,val[:,34],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2],FillüberundunterPMT],axis=1)
    block4=np.concatenate([FillüberundunterPMT,val[:,83],FillziwschenPMTs,val[:,67],FillziwschenPMTs,val[:,51],FillziwschenPMTs,val[:,35],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3],FillüberundunterPMT],axis=1)
    block5=np.concatenate([FillüberundunterPMT,val[:,84],FillziwschenPMTs,val[:,68],FillziwschenPMTs,val[:,52],FillziwschenPMTs,val[:,36],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4],FillüberundunterPMT],axis=1)
    block6=np.concatenate([FillüberundunterPMT,val[:,85],FillziwschenPMTs,val[:,69],FillziwschenPMTs,val[:,53],FillziwschenPMTs,val[:,37],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5],FillüberundunterPMT],axis=1)
    block7=np.concatenate([FillüberundunterPMT,val[:,86],FillziwschenPMTs,val[:,70],FillziwschenPMTs,val[:,54],FillziwschenPMTs,val[:,38],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6],FillüberundunterPMT],axis=1)
    block8=np.concatenate([FillüberundunterPMT,val[:,87],FillziwschenPMTs,val[:,71],FillziwschenPMTs,val[:,55],FillziwschenPMTs,val[:,39],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7],FillüberundunterPMT],axis=1)
    block9=np.concatenate([FillüberundunterPMT,val[:,88],FillziwschenPMTs,val[:,72],FillziwschenPMTs,val[:,56],FillziwschenPMTs,val[:,40],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8],FillüberundunterPMT],axis=1)
    block10=np.concatenate([FillüberundunterPMT,val[:,89],FillziwschenPMTs,val[:,73],FillziwschenPMTs,val[:,57],FillziwschenPMTs,val[:,41],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9],FillüberundunterPMT],axis=1)
    block11=np.concatenate([FillüberundunterPMT,val[:,90],FillziwschenPMTs,val[:,74],FillziwschenPMTs,val[:,58],FillziwschenPMTs,val[:,42],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10],FillüberundunterPMT],axis=1)
    block12=np.concatenate([FillüberundunterPMT,val[:,91],FillziwschenPMTs,val[:,75],FillziwschenPMTs,val[:,59],FillziwschenPMTs,val[:,43],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11],FillüberundunterPMT],axis=1)
    block13=np.concatenate([FillüberundunterPMT,val[:,92],FillziwschenPMTs,val[:,76],FillziwschenPMTs,val[:,60],FillziwschenPMTs,val[:,44],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12],FillüberundunterPMT],axis=1)
    block14=np.concatenate([FillüberundunterPMT,val[:,93],FillziwschenPMTs,val[:,77],FillziwschenPMTs,val[:,61],FillziwschenPMTs,val[:,45],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13],FillüberundunterPMT],axis=1)
    block15=np.concatenate([FillüberundunterPMT,val[:,94],FillziwschenPMTs,val[:,78],FillziwschenPMTs,val[:,62],FillziwschenPMTs,val[:,46],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14],FillüberundunterPMT],axis=1)
    block16=np.concatenate([FillüberundunterPMT,val[:,95],FillziwschenPMTs,val[:,79],FillziwschenPMTs,val[:,63],FillziwschenPMTs,val[:,47],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15],FillüberundunterPMT],axis=1)
    del val
    
    #print("PMT Zyklus fertig: {}".format(i))
    
    
    fertig=np.concatenate([LP1,nullerspalte,block1],axis=2)
    del LP1,block1
    fertig=np.concatenate([fertig,nullerspalte,block2,nullerspalte,LP2],axis=2)
    del block2,LP2
    fertig=np.concatenate([fertig,nullerspalte,block3,nullerspalte,block4],axis=2)
    del block3,block4
    fertig=np.concatenate([fertig,nullerspalte,LP3,nullerspalte,block5],axis=2)
    del LP3,block5
    fertig=np.concatenate([fertig,nullerspalte,block6,nullerspalte,LP4],axis=2)
    del block6, LP4
    fertig=np.concatenate([fertig,nullerspalte,block7,nullerspalte,block8],axis=2)
    del block7,block8
    fertig=np.concatenate([fertig,nullerspalte,LP5,nullerspalte,block9],axis=2)
    del LP5,block9
    fertig=np.concatenate([fertig,nullerspalte,block10,nullerspalte,LP6],axis=2)
    del block10,LP6
    fertig=np.concatenate([fertig,nullerspalte,block11,nullerspalte,block12],axis=2)
    del block11,block12
    fertig=np.concatenate([fertig,nullerspalte,LP7,nullerspalte,block13],axis=2)
    del LP7, block13
    fertig=np.concatenate([fertig,nullerspalte,block14,nullerspalte,LP8],axis=2)
    del block14,LP8
    fertig=np.concatenate([fertig,nullerspalte,block15,nullerspalte],axis=2)
    del block15
    fertig=np.concatenate([fertig,block16],axis=2)
    del block16
    #print(fertig.shape)
    #print("BigMapCharge Zyklus fertig: {}".format(i))
    
    
    ############################################### TIME #################################
    
    
    all_values_Lappd = np.load('Temp/TimeLAPPD.npy')
    
    LAPPD1array = all_values_Lappd[b:bE,0:400].reshape(-1,20,20,1)
    LAPPD2array = all_values_Lappd[b:bE,400:800].reshape(-1,20,20,1)
    LAPPD3array = all_values_Lappd[b:bE,800:1200].reshape(-1,20,20,1)
    LAPPD4array = all_values_Lappd[b:bE,1199+1:1599+1].reshape(-1,20,20,1)
    LAPPD5array = all_values_Lappd[b:bE,1599+1:1999+1].reshape(-1,20,20,1)
    LAPPD6array = all_values_Lappd[b:bE,1999+1:2399+1].reshape(-1,20,20,1)
    LAPPD7array = all_values_Lappd[b:bE,2399+1:2799+1].reshape(-1,20,20,1)
    LAPPD8array = all_values_Lappd[b:bE,2799+1:3199+1].reshape(-1,20,20,1)
    LAPPD9array = all_values_Lappd[b:bE,3199+1:3599+1].reshape(-1,20,20,1)
    LAPPD10array = all_values_Lappd[b:bE,3599+1:3999+1].reshape(-1,20,20,1)
    LAPPD11array = all_values_Lappd[b:bE,3999+1:4399+1].reshape(-1,20,20,1)
    LAPPD12array = all_values_Lappd[b:bE,4399+1:4799+1].reshape(-1,20,20,1)
    LAPPD13array = all_values_Lappd[b:bE,4799+1:5199+1].reshape(-1,20,20,1)
    LAPPD14array = all_values_Lappd[b:bE,5199+1:5599+1].reshape(-1,20,20,1)
    LAPPD15array = all_values_Lappd[b:bE,5599+1:5999+1].reshape(-1,20,20,1)
    LAPPD16array = all_values_Lappd[b:bE,5999+1:6399+1].reshape(-1,20,20,1)
    LAPPD17array = all_values_Lappd[b:bE,6400:6799+1].reshape(-1,20,20,1)
    LAPPD18array = all_values_Lappd[b:bE,6800:7199+1].reshape(-1,20,20,1)
    LAPPD19array = all_values_Lappd[b:bE,7200:7599+1].reshape(-1,20,20,1)
    LAPPD20array = all_values_Lappd[b:bE,7600:7999+1].reshape(-1,20,20,1)
    LAPPD21array = all_values_Lappd[b:bE,8000:8399+1].reshape(-1,20,20,1)
    LAPPD22array = all_values_Lappd[b:bE,8400:8799+1].reshape(-1,20,20,1)
    LAPPD23array = all_values_Lappd[b:bE,8800:9199+1].reshape(-1,20,20,1)
    LAPPD24array = all_values_Lappd[b:bE,9200:9599+1].reshape(-1,20,20,1)

    
    a=len(LAPPD1array)
    FillüLappd3 = np.zeros((a,51,20,1))
    FillzwLAPPD= np.zeros((a,22,20,1))
    FillunterLAPPD1=np.zeros((a,54,20,1))


    LP1=np.concatenate([FillüLappd3,LAPPD3array,FillzwLAPPD,LAPPD2array,FillzwLAPPD,LAPPD1array,FillunterLAPPD1], axis=1)
    del LAPPD1array,LAPPD2array,LAPPD3array
    LP2=np.concatenate([FillüLappd3,LAPPD6array,FillzwLAPPD,LAPPD5array,FillzwLAPPD,LAPPD4array,FillunterLAPPD1], axis=1)
    del LAPPD4array,LAPPD5array,LAPPD6array
    LP3=np.concatenate([FillüLappd3,LAPPD9array,FillzwLAPPD,LAPPD8array,FillzwLAPPD,LAPPD7array,FillunterLAPPD1], axis=1)
    del LAPPD7array,LAPPD8array,LAPPD9array
    LP4=np.concatenate([FillüLappd3,LAPPD12array,FillzwLAPPD,LAPPD11array,FillzwLAPPD,LAPPD10array,FillunterLAPPD1], axis=1)
    del LAPPD10array,LAPPD11array,LAPPD12array
    LP5=np.concatenate([FillüLappd3,LAPPD15array,FillzwLAPPD,LAPPD14array,FillzwLAPPD,LAPPD13array,FillunterLAPPD1], axis=1)
    del LAPPD13array,LAPPD14array,LAPPD15array
    LP6=np.concatenate([FillüLappd3,LAPPD18array,FillzwLAPPD,LAPPD17array,FillzwLAPPD,LAPPD16array,FillunterLAPPD1], axis=1)
    del LAPPD16array,LAPPD17array,LAPPD18array
    LP7=np.concatenate([FillüLappd3,LAPPD21array,FillzwLAPPD,LAPPD20array,FillzwLAPPD,LAPPD19array,FillunterLAPPD1], axis=1)
    del LAPPD19array,LAPPD20array,LAPPD21array
    LP8=np.concatenate([FillüLappd3,LAPPD24array,FillzwLAPPD,LAPPD23array,FillzwLAPPD,LAPPD22array,FillunterLAPPD1], axis=1)
    del LAPPD22array,LAPPD23array,LAPPD24array

    del all_values_Lappd  
    #print("LAPPD Zyklus fertig: {}".format(i))
    
    all_values = np.load('Temp/TimePMT.npy')
    
    PMT_array =defaultdict(dict)
    val=[]

    for event in range(b,bE):
        for x in range(0, 96):
            PMT_array[event][x] = float(all_values[event,x:x+1])*np.ones((20,20)) 
        val.append(list(PMT_array[event].values()))
    del all_values, PMT_array    

    
    val= np.array(val,dtype = np.float).reshape((-1,96,20,20,1))
    FillüberundunterPMT = np.zeros((a,42,20,1))
    FillziwschenPMTs = np.zeros((a,1,20,1))
    nullerspalte=np.zeros((a,209,1,1))

    block1=np.concatenate([FillüberundunterPMT,val[:,80],FillziwschenPMTs,val[:,64],FillziwschenPMTs,val[:,48],FillziwschenPMTs,val[:,32],FillziwschenPMTs,val[:,16],FillziwschenPMTs,val[:,0],FillüberundunterPMT],axis=1)
    block2=np.concatenate([FillüberundunterPMT,val[:,81],FillziwschenPMTs,val[:,65],FillziwschenPMTs,val[:,49],FillziwschenPMTs,val[:,33],FillziwschenPMTs,val[:,17],FillziwschenPMTs,val[:,1],FillüberundunterPMT],axis=1)
    block3=np.concatenate([FillüberundunterPMT,val[:,82],FillziwschenPMTs,val[:,66],FillziwschenPMTs,val[:,50],FillziwschenPMTs,val[:,34],FillziwschenPMTs,val[:,18],FillziwschenPMTs,val[:,2],FillüberundunterPMT],axis=1)
    block4=np.concatenate([FillüberundunterPMT,val[:,83],FillziwschenPMTs,val[:,67],FillziwschenPMTs,val[:,51],FillziwschenPMTs,val[:,35],FillziwschenPMTs,val[:,19],FillziwschenPMTs,val[:,3],FillüberundunterPMT],axis=1)
    block5=np.concatenate([FillüberundunterPMT,val[:,84],FillziwschenPMTs,val[:,68],FillziwschenPMTs,val[:,52],FillziwschenPMTs,val[:,36],FillziwschenPMTs,val[:,20],FillziwschenPMTs,val[:,4],FillüberundunterPMT],axis=1)
    block6=np.concatenate([FillüberundunterPMT,val[:,85],FillziwschenPMTs,val[:,69],FillziwschenPMTs,val[:,53],FillziwschenPMTs,val[:,37],FillziwschenPMTs,val[:,21],FillziwschenPMTs,val[:,5],FillüberundunterPMT],axis=1)
    block7=np.concatenate([FillüberundunterPMT,val[:,86],FillziwschenPMTs,val[:,70],FillziwschenPMTs,val[:,54],FillziwschenPMTs,val[:,38],FillziwschenPMTs,val[:,22],FillziwschenPMTs,val[:,6],FillüberundunterPMT],axis=1)
    block8=np.concatenate([FillüberundunterPMT,val[:,87],FillziwschenPMTs,val[:,71],FillziwschenPMTs,val[:,55],FillziwschenPMTs,val[:,39],FillziwschenPMTs,val[:,23],FillziwschenPMTs,val[:,7],FillüberundunterPMT],axis=1)
    block9=np.concatenate([FillüberundunterPMT,val[:,88],FillziwschenPMTs,val[:,72],FillziwschenPMTs,val[:,56],FillziwschenPMTs,val[:,40],FillziwschenPMTs,val[:,24],FillziwschenPMTs,val[:,8],FillüberundunterPMT],axis=1)
    block10=np.concatenate([FillüberundunterPMT,val[:,89],FillziwschenPMTs,val[:,73],FillziwschenPMTs,val[:,57],FillziwschenPMTs,val[:,41],FillziwschenPMTs,val[:,25],FillziwschenPMTs,val[:,9],FillüberundunterPMT],axis=1)
    block11=np.concatenate([FillüberundunterPMT,val[:,90],FillziwschenPMTs,val[:,74],FillziwschenPMTs,val[:,58],FillziwschenPMTs,val[:,42],FillziwschenPMTs,val[:,26],FillziwschenPMTs,val[:,10],FillüberundunterPMT],axis=1)
    block12=np.concatenate([FillüberundunterPMT,val[:,91],FillziwschenPMTs,val[:,75],FillziwschenPMTs,val[:,59],FillziwschenPMTs,val[:,43],FillziwschenPMTs,val[:,27],FillziwschenPMTs,val[:,11],FillüberundunterPMT],axis=1)
    block13=np.concatenate([FillüberundunterPMT,val[:,92],FillziwschenPMTs,val[:,76],FillziwschenPMTs,val[:,60],FillziwschenPMTs,val[:,44],FillziwschenPMTs,val[:,28],FillziwschenPMTs,val[:,12],FillüberundunterPMT],axis=1)
    block14=np.concatenate([FillüberundunterPMT,val[:,93],FillziwschenPMTs,val[:,77],FillziwschenPMTs,val[:,61],FillziwschenPMTs,val[:,45],FillziwschenPMTs,val[:,29],FillziwschenPMTs,val[:,13],FillüberundunterPMT],axis=1)
    block15=np.concatenate([FillüberundunterPMT,val[:,94],FillziwschenPMTs,val[:,78],FillziwschenPMTs,val[:,62],FillziwschenPMTs,val[:,46],FillziwschenPMTs,val[:,30],FillziwschenPMTs,val[:,14],FillüberundunterPMT],axis=1)
    block16=np.concatenate([FillüberundunterPMT,val[:,95],FillziwschenPMTs,val[:,79],FillziwschenPMTs,val[:,63],FillziwschenPMTs,val[:,47],FillziwschenPMTs,val[:,31],FillziwschenPMTs,val[:,15],FillüberundunterPMT],axis=1)
    del val
    
    
    fertigTime=np.concatenate([LP1,nullerspalte,block1],axis=2)
    del LP1,block1
    #print("Fertig 1/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block2,nullerspalte,LP2],axis=2)
    del block2,LP2
    #print("Fertig 2/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block3,nullerspalte,block4],axis=2)
    del block3,block4
    #print("Fertig 3/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,LP3,nullerspalte,block5],axis=2)
    del LP3,block5
    #print("Fertig 4/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block6,nullerspalte,LP4],axis=2)
    del block6, LP4
    #print("Fertig 5/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block7,nullerspalte,block8],axis=2)
    del block7,block8
    #print("Fertig 6/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,LP5,nullerspalte,block9],axis=2)
    del LP5,block9
    #print("Fertig 7/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block10,nullerspalte,LP6],axis=2)
    del block10,LP6
    #print("Fertig 8/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block11,nullerspalte,block12],axis=2)
    del block11,block12
    #print("Fertig 9/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,LP7,nullerspalte,block13],axis=2)
    del LP7, block13
    #print("Fertig 10/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block14,nullerspalte,LP8],axis=2)
    del block14,LP8
    #print("Fertig 11/10")
    fertigTime=np.concatenate([fertigTime,nullerspalte,block15,nullerspalte],axis=2)
    del block15
    #print("Fertig 12/10")
    fertigTime=np.concatenate([fertigTime,block16],axis=2)
    del block16
    #print("Fertig 13/10")
    #print("Fertig mit traingTime und die Shape ist: ", fertigTime.shape)
    
    
    trueVal= np.load('Temp/True.npy')
    
    training_data=list(zip(fertig,fertigTime
                          # ,trueVal[b:be]
                          ))
    preX1 =[]
    preX2 =[]

    for x in training_data:
        #preX1A = np.array([x[0]]).reshape(-1, 20,16, 1)
        preX1.append(x[0])
    #    preX2A = np.array([x[1]]).reshape(-1, 20,16, 1)
        preX2.append(x[1])


    training_data = list(zip(preX1, preX2))
    training_data = np.array(training_data).reshape(-1,2,209,503)
    #print("Shape ist: ", training_data.shape)
    training_data=np.transpose(training_data, (0, 2, 3,1))
    training_data=np.squeeze(training_data, axis=0)
    


    

    #print("Shape ist: ", training_data.shape)
    trueValu=trueVal[b:bE]
    
    
    np.savez_compressed('Training/BeamlikeSingle/BeamlikeS{}'.format(i), X=training_data, Y=trueValu)
    print("Fertig mit Speichern von {}".format(i))
    
    #if (i ==0):
       # break
    b=b+batchsize
# Out:
# HBox(children=(IntProgress(value=0, max=32955), HTML(value='')))
# Fertig mit Speichern von 0
# Fertig mit Speichern von 1
# Fertig mit Speichern von 2
# Fertig mit Speichern von 3
# Fertig mit Speichern von 4
# Fertig mit Speichern von 5
# Fertig mit Speichern von 6
# Fertig mit Speichern von 7
# Fertig mit Speichern von 8
# Fertig mit Speichern von 9
# Fertig mit Speichern von 10
# Fertig mit Speichern von 11
# Fertig mit Speichern von 12
# Fertig mit Speichern von 13
# Fertig mit Speichern von 14
# Fertig mit Speichern von 15
# Fertig mit Speichern von 16
# Fertig mit Speichern von 17
# Fertig mit Speichern von 18
# Fertig mit Speichern von 19
# Fertig mit Speichern von 20
# Fertig mit Speichern von 21
# Fertig mit Speichern von 22
# Fertig mit Speichern von 23
# Fertig mit Speichern von 24
# Fertig mit Speichern von 25
# Fertig mit Speichern von 26
# Fertig mit Speichern von 27
# Fertig mit Speichern von 28
# Fertig mit Speichern von 29
# Fertig mit Speichern von 30
# Fertig mit Speichern von 31
# Fertig mit Speichern von 32
# Fertig mit Speichern von 33
# Fertig mit Speichern von 34
# Fertig mit Speichern von 35
# Fertig mit Speichern von 36
# Fertig mit Speichern von 37
# Fertig mit Speichern von 38
# Fertig mit Speichern von 39
# Fertig mit Speichern von 40
# Fertig mit Speichern von 41
# Fertig mit Speichern von 42
# Fertig mit Speichern von 43
# Fertig mit Speichern von 44
# Fertig mit Speichern von 45
# Fertig mit Speichern von 46
# Fertig mit Speichern von 47
# Fertig mit Speichern von 48
# Fertig mit Speichern von 49
# Fertig mit Speichern von 50
# Fertig mit Speichern von 51
# Fertig mit Speichern von 52
# Fertig mit Speichern von 53
# Fertig mit Speichern von 54
# Fertig mit Speichern von 55
# Fertig mit Speichern von 56
# Fertig mit Speichern von 57
# Fertig mit Speichern von 58
# Fertig mit Speichern von 59
# Fertig mit Speichern von 60
# Fertig mit Speichern von 61
# Fertig mit Speichern von 62
# Fertig mit Speichern von 63
# Fertig mit Speichern von 64
# Fertig mit Speichern von 65
# Fertig mit Speichern von 66
# Fertig mit Speichern von 67
# Fertig mit Speichern von 68
# Fertig mit Speichern von 69
# Fertig mit Speichern von 70
# Fertig mit Speichern von 71
# Fertig mit Speichern von 72
# Fertig mit Speichern von 73
# Fertig mit Speichern von 74
# Fertig mit Speichern von 75
# Fertig mit Speichern von 76
# Fertig mit Speichern von 77
# Fertig mit Speichern von 78
# Fertig mit Speichern von 79
# Fertig mit Speichern von 80
# Fertig mit Speichern von 81
# Fertig mit Speichern von 82
# Fertig mit Speichern von 83
# Fertig mit Speichern von 84
# Fertig mit Speichern von 85
# Fertig mit Speichern von 86
# Fertig mit Speichern von 87
# Fertig mit Speichern von 88
# Fertig mit Speichern von 89
# Fertig mit Speichern von 90
# Fertig mit Speichern von 91
# Fertig mit Speichern von 92
# Fertig mit Speichern von 93
# Fertig mit Speichern von 94
# Fertig mit Speichern von 95
# Fertig mit Speichern von 96
# Fertig mit Speichern von 97
# Fertig mit Speichern von 98
# Fertig mit Speichern von 99
# Fertig mit Speichern von 100
# Fertig mit Speichern von 101
# Fertig mit Speichern von 102
# Fertig mit Speichern von 103
# Fertig mit Speichern von 104
# Fertig mit Speichern von 105
# Fertig mit Speichern von 106
# Fertig mit Speichern von 107
# Fertig mit Speichern von 108
# Fertig mit Speichern von 109
# Fertig mit Speichern von 110
# Fertig mit Speichern von 111
# Fertig mit Speichern von 112
# Fertig mit Speichern von 113
# Fertig mit Speichern von 114
# Fertig mit Speichern von 115
# Fertig mit Speichern von 116
# Fertig mit Speichern von 117
# Fertig mit Speichern von 118
# Fertig mit Speichern von 119
# Fertig mit Speichern von 120
# Fertig mit Speichern von 121
# Fertig mit Speichern von 122
# Fertig mit Speichern von 123
# Fertig mit Speichern von 124
# Fertig mit Speichern von 125
# Fertig mit Speichern von 126
# Fertig mit Speichern von 127
# Fertig mit Speichern von 128
# Fertig mit Speichern von 129
# Fertig mit Speichern von 130
# Fertig mit Speichern von 131
# Fertig mit Speichern von 132
# Fertig mit Speichern von 133
# Fertig mit Speichern von 134
# Fertig mit Speichern von 135
# Fertig mit Speichern von 136
# Fertig mit Speichern von 137
# Fertig mit Speichern von 138
# Fertig mit Speichern von 139
# Fertig mit Speichern von 140
# Fertig mit Speichern von 141
# Fertig mit Speichern von 142
# Fertig mit Speichern von 143
# Fertig mit Speichern von 144
# Fertig mit Speichern von 145
# Fertig mit Speichern von 146
# Fertig mit Speichern von 147
# Fertig mit Speichern von 148
# Fertig mit Speichern von 149
# Fertig mit Speichern von 150
# Fertig mit Speichern von 151
# Fertig mit Speichern von 152
# Fertig mit Speichern von 153
# Fertig mit Speichern von 154
# Fertig mit Speichern von 155
# Fertig mit Speichern von 156
# Fertig mit Speichern von 157
# Fertig mit Speichern von 158
# Fertig mit Speichern von 159
# Fertig mit Speichern von 160
# Fertig mit Speichern von 161
# Fertig mit Speichern von 162
# Fertig mit Speichern von 163
# Fertig mit Speichern von 164
# Fertig mit Speichern von 165
# Fertig mit Speichern von 166
# Fertig mit Speichern von 167
# Fertig mit Speichern von 168
# Fertig mit Speichern von 169
# Fertig mit Speichern von 170
# Fertig mit Speichern von 171
# Fertig mit Speichern von 172
# Fertig mit Speichern von 173
# Fertig mit Speichern von 174
# Fertig mit Speichern von 175
# Fertig mit Speichern von 176
# Fertig mit Speichern von 177
# Fertig mit Speichern von 178
# Fertig mit Speichern von 179
# Fertig mit Speichern von 180
# Fertig mit Speichern von 181
# Fertig mit Speichern von 182
# Fertig mit Speichern von 183
# Fertig mit Speichern von 184
# Fertig mit Speichern von 185
# Fertig mit Speichern von 186
# Fertig mit Speichern von 187
# Fertig mit Speichern von 188
# Fertig mit Speichern von 189
# Fertig mit Speichern von 190
# Fertig mit Speichern von 191
# Fertig mit Speichern von 192
# Fertig mit Speichern von 193
# Fertig mit Speichern von 194
# Fertig mit Speichern von 195
# Fertig mit Speichern von 196
# Fertig mit Speichern von 197
# Fertig mit Speichern von 198
# Fertig mit Speichern von 199
# Fertig mit Speichern von 200
# Fertig mit Speichern von 201
# Fertig mit Speichern von 202
# Fertig mit Speichern von 203
# Fertig mit Speichern von 204
# Fertig mit Speichern von 205
# Fertig mit Speichern von 206
# Fertig mit Speichern von 207
# Fertig mit Speichern von 208
# Fertig mit Speichern von 209
# Fertig mit Speichern von 210
# Fertig mit Speichern von 211
# Fertig mit Speichern von 212
# Fertig mit Speichern von 213
# Fertig mit Speichern von 214
# Fertig mit Speichern von 215
# Fertig mit Speichern von 216
# Fertig mit Speichern von 217
# Fertig mit Speichern von 218
# Fertig mit Speichern von 219
# Fertig mit Speichern von 220
# Fertig mit Speichern von 221
# Fertig mit Speichern von 222
# Fertig mit Speichern von 223
# Fertig mit Speichern von 224
# Fertig mit Speichern von 225
# Fertig mit Speichern von 226
# Fertig mit Speichern von 227
# Fertig mit Speichern von 228
# Fertig mit Speichern von 229
# Fertig mit Speichern von 230
# Fertig mit Speichern von 231
# Fertig mit Speichern von 232
# Fertig mit Speichern von 233
# Fertig mit Speichern von 234
# Fertig mit Speichern von 235
# Fertig mit Speichern von 236
# Fertig mit Speichern von 237
# Fertig mit Speichern von 238
# Fertig mit Speichern von 239
# Fertig mit Speichern von 240
# Fertig mit Speichern von 241
# Fertig mit Speichern von 242
# Fertig mit Speichern von 243
# Fertig mit Speichern von 244
# Fertig mit Speichern von 245
# Fertig mit Speichern von 246
# Fertig mit Speichern von 247
# Fertig mit Speichern von 248
# Fertig mit Speichern von 249
# Fertig mit Speichern von 250
# Fertig mit Speichern von 251
# Fertig mit Speichern von 252
# Fertig mit Speichern von 253
# Fertig mit Speichern von 254
# Fertig mit Speichern von 255
# Fertig mit Speichern von 256
# Fertig mit Speichern von 257
# Fertig mit Speichern von 258
# Fertig mit Speichern von 259
# Fertig mit Speichern von 260
# Fertig mit Speichern von 261
# Fertig mit Speichern von 262
# Fertig mit Speichern von 263
# Fertig mit Speichern von 264
# Fertig mit Speichern von 265
# Fertig mit Speichern von 266
# Fertig mit Speichern von 267
# Fertig mit Speichern von 268
# Fertig mit Speichern von 269
# Fertig mit Speichern von 270
# Fertig mit Speichern von 271
# Fertig mit Speichern von 272
# Fertig mit Speichern von 273
# Fertig mit Speichern von 274
# Fertig mit Speichern von 275
# Fertig mit Speichern von 276
# Fertig mit Speichern von 277
# Fertig mit Speichern von 278
# Fertig mit Speichern von 279
# Fertig mit Speichern von 280
# Fertig mit Speichern von 281
# Fertig mit Speichern von 282
# Fertig mit Speichern von 283
# Fertig mit Speichern von 284
# Fertig mit Speichern von 285
# Fertig mit Speichern von 286
# Fertig mit Speichern von 287
# Fertig mit Speichern von 288
# Fertig mit Speichern von 289
# Fertig mit Speichern von 290
# Fertig mit Speichern von 291
# Fertig mit Speichern von 292
# Fertig mit Speichern von 293
# Fertig mit Speichern von 294
# Fertig mit Speichern von 295
# Fertig mit Speichern von 296
# Fertig mit Speichern von 297
# Fertig mit Speichern von 298
# Fertig mit Speichern von 299
# Fertig mit Speichern von 300
# Fertig mit Speichern von 301
# Fertig mit Speichern von 302
# Fertig mit Speichern von 303
# Fertig mit Speichern von 304
# Fertig mit Speichern von 305
# Fertig mit Speichern von 306
# Fertig mit Speichern von 307
# Fertig mit Speichern von 308
# Fertig mit Speichern von 309
# Fertig mit Speichern von 310
# Fertig mit Speichern von 311
# Fertig mit Speichern von 312
# Fertig mit Speichern von 313
# Fertig mit Speichern von 314
# Fertig mit Speichern von 315
# Fertig mit Speichern von 316
# Fertig mit Speichern von 317
# Fertig mit Speichern von 318
# Fertig mit Speichern von 319
# Fertig mit Speichern von 320
# Fertig mit Speichern von 321
# Fertig mit Speichern von 322
# Fertig mit Speichern von 323
# Fertig mit Speichern von 324
# Fertig mit Speichern von 325
# Fertig mit Speichern von 326
# Fertig mit Speichern von 327
# Fertig mit Speichern von 328
# Fertig mit Speichern von 329
# Fertig mit Speichern von 330
# Fertig mit Speichern von 331
# Fertig mit Speichern von 332
# Fertig mit Speichern von 333
# Fertig mit Speichern von 334
# Fertig mit Speichern von 335
# Fertig mit Speichern von 336
# Fertig mit Speichern von 337
# Fertig mit Speichern von 338
# Fertig mit Speichern von 339
# Fertig mit Speichern von 340
# Fertig mit Speichern von 341
# Fertig mit Speichern von 342
# Fertig mit Speichern von 343
# Fertig mit Speichern von 344
# Fertig mit Speichern von 345
# Fertig mit Speichern von 346
# Fertig mit Speichern von 347
# Fertig mit Speichern von 348
# Fertig mit Speichern von 349
# Fertig mit Speichern von 350
# Fertig mit Speichern von 351
# Fertig mit Speichern von 352
# Fertig mit Speichern von 353
# Fertig mit Speichern von 354
# Fertig mit Speichern von 355
# Fertig mit Speichern von 356
# Fertig mit Speichern von 357
# Fertig mit Speichern von 358
# Fertig mit Speichern von 359
# Fertig mit Speichern von 360
# Fertig mit Speichern von 361
# Fertig mit Speichern von 362
# Fertig mit Speichern von 363
# Fertig mit Speichern von 364
# Fertig mit Speichern von 365
# Fertig mit Speichern von 366
# Fertig mit Speichern von 367
# Fertig mit Speichern von 368
# Fertig mit Speichern von 369
# Fertig mit Speichern von 370
# Fertig mit Speichern von 371
# Fertig mit Speichern von 372
# Fertig mit Speichern von 373
# Fertig mit Speichern von 374
# Fertig mit Speichern von 375
# Fertig mit Speichern von 376
# Fertig mit Speichern von 377
# Fertig mit Speichern von 378
# Fertig mit Speichern von 379
# Fertig mit Speichern von 380
# Fertig mit Speichern von 381
# Fertig mit Speichern von 382
# Fertig mit Speichern von 383
# Fertig mit Speichern von 384
# Fertig mit Speichern von 385
# Fertig mit Speichern von 386
# Fertig mit Speichern von 387
# Fertig mit Speichern von 388
# Fertig mit Speichern von 389
# Fertig mit Speichern von 390
# Fertig mit Speichern von 391
# Fertig mit Speichern von 392
# Fertig mit Speichern von 393
# Fertig mit Speichern von 394
# Fertig mit Speichern von 395
# Fertig mit Speichern von 396
# Fertig mit Speichern von 397
# Fertig mit Speichern von 398
# Fertig mit Speichern von 399
# Fertig mit Speichern von 400
# Fertig mit Speichern von 401
# Fertig mit Speichern von 402
# Fertig mit Speichern von 403
# Fertig mit Speichern von 404
# Fertig mit Speichern von 405
# Fertig mit Speichern von 406
# Fertig mit Speichern von 407
# Fertig mit Speichern von 408
# Fertig mit Speichern von 409
# Fertig mit Speichern von 410
# Fertig mit Speichern von 411
# Fertig mit Speichern von 412
# Fertig mit Speichern von 413
# Fertig mit Speichern von 414
# Fertig mit Speichern von 415
# Fertig mit Speichern von 416
# Fertig mit Speichern von 417
# Fertig mit Speichern von 418
# Fertig mit Speichern von 419
# Fertig mit Speichern von 420
# Fertig mit Speichern von 421
# Fertig mit Speichern von 422
# Fertig mit Speichern von 423
# Fertig mit Speichern von 424
# Fertig mit Speichern von 425
# Fertig mit Speichern von 426
# Fertig mit Speichern von 427
# Fertig mit Speichern von 428
# Fertig mit Speichern von 429
# Fertig mit Speichern von 430
# Fertig mit Speichern von 431
# Fertig mit Speichern von 432
# Fertig mit Speichern von 433
# Fertig mit Speichern von 434
# Fertig mit Speichern von 435
# Fertig mit Speichern von 436
# Fertig mit Speichern von 437
# Fertig mit Speichern von 438
# Fertig mit Speichern von 439
# Fertig mit Speichern von 440
# Fertig mit Speichern von 441
# Fertig mit Speichern von 442
# Fertig mit Speichern von 443
# Fertig mit Speichern von 444
# Fertig mit Speichern von 445
# Fertig mit Speichern von 446
# Fertig mit Speichern von 447
# Fertig mit Speichern von 448
# Fertig mit Speichern von 449
# Fertig mit Speichern von 450
# Fertig mit Speichern von 451
# Fertig mit Speichern von 452
# Fertig mit Speichern von 453
# Fertig mit Speichern von 454
# Fertig mit Speichern von 455
# Fertig mit Speichern von 456
# Fertig mit Speichern von 457
# Fertig mit Speichern von 458
# Fertig mit Speichern von 459
# Fertig mit Speichern von 460
# Fertig mit Speichern von 461
# Fertig mit Speichern von 462
# Fertig mit Speichern von 463
# Fertig mit Speichern von 464
# Fertig mit Speichern von 465
# Fertig mit Speichern von 466
# Fertig mit Speichern von 467
# Fertig mit Speichern von 468
# Fertig mit Speichern von 469
# Fertig mit Speichern von 470
# Fertig mit Speichern von 471
# Fertig mit Speichern von 472
# Fertig mit Speichern von 473
# Fertig mit Speichern von 474
# Fertig mit Speichern von 475
# Fertig mit Speichern von 476
# Fertig mit Speichern von 477
# Fertig mit Speichern von 478
# Fertig mit Speichern von 479
# Fertig mit Speichern von 480
# Fertig mit Speichern von 481
# Fertig mit Speichern von 482
# Fertig mit Speichern von 483
# Fertig mit Speichern von 484
# Fertig mit Speichern von 485
# Fertig mit Speichern von 486
# Fertig mit Speichern von 487
# Fertig mit Speichern von 488
# Fertig mit Speichern von 489
# Fertig mit Speichern von 490
# Fertig mit Speichern von 491
# Fertig mit Speichern von 492
# Fertig mit Speichern von 493
# Fertig mit Speichern von 494
# Fertig mit Speichern von 495
# Fertig mit Speichern von 496
# Fertig mit Speichern von 497
# Fertig mit Speichern von 498
# Fertig mit Speichern von 499
# Fertig mit Speichern von 500
# Fertig mit Speichern von 501
# Fertig mit Speichern von 502
# Fertig mit Speichern von 503
# Fertig mit Speichern von 504
# Fertig mit Speichern von 505
# Fertig mit Speichern von 506
# Fertig mit Speichern von 507
# Fertig mit Speichern von 508
# Fertig mit Speichern von 509
# Fertig mit Speichern von 510
# Fertig mit Speichern von 511
# Fertig mit Speichern von 512
# Fertig mit Speichern von 513
# Fertig mit Speichern von 514
# Fertig mit Speichern von 515
# Fertig mit Speichern von 516
# Fertig mit Speichern von 517
# Fertig mit Speichern von 518
# Fertig mit Speichern von 519
# Fertig mit Speichern von 520
# Fertig mit Speichern von 521
# Fertig mit Speichern von 522
# Fertig mit Speichern von 523
# Fertig mit Speichern von 524
# Fertig mit Speichern von 525
# Fertig mit Speichern von 526
# Fertig mit Speichern von 527
# Fertig mit Speichern von 528
# Fertig mit Speichern von 529
# Fertig mit Speichern von 530
# Fertig mit Speichern von 531
# Fertig mit Speichern von 532
# Fertig mit Speichern von 533
# Fertig mit Speichern von 534
# Fertig mit Speichern von 535
# Fertig mit Speichern von 536
# Fertig mit Speichern von 537
# Fertig mit Speichern von 538
# Fertig mit Speichern von 539
# Fertig mit Speichern von 540
# Fertig mit Speichern von 541
# Fertig mit Speichern von 542
# Fertig mit Speichern von 543
# Fertig mit Speichern von 544
# Fertig mit Speichern von 545
# Fertig mit Speichern von 546
# Fertig mit Speichern von 547
# Fertig mit Speichern von 548
# Fertig mit Speichern von 549
# Fertig mit Speichern von 550
# Fertig mit Speichern von 551
# Fertig mit Speichern von 552
# Fertig mit Speichern von 553
# Fertig mit Speichern von 554
# Fertig mit Speichern von 555
# Fertig mit Speichern von 556
# Fertig mit Speichern von 557
# Fertig mit Speichern von 558
# Fertig mit Speichern von 559
# Fertig mit Speichern von 560
# Fertig mit Speichern von 561
# Fertig mit Speichern von 562
# Fertig mit Speichern von 563
# Fertig mit Speichern von 564
# Fertig mit Speichern von 565
# Fertig mit Speichern von 566
# Fertig mit Speichern von 567
# Fertig mit Speichern von 568
# Fertig mit Speichern von 569
# Fertig mit Speichern von 570
# Fertig mit Speichern von 571
# Fertig mit Speichern von 572
# Fertig mit Speichern von 573
# Fertig mit Speichern von 574
# Fertig mit Speichern von 575
# Fertig mit Speichern von 576
# Fertig mit Speichern von 577
# Fertig mit Speichern von 578
# Fertig mit Speichern von 579
# Fertig mit Speichern von 580
# Fertig mit Speichern von 581
# Fertig mit Speichern von 582
# Fertig mit Speichern von 583
# Fertig mit Speichern von 584
# Fertig mit Speichern von 585
# Fertig mit Speichern von 586
# Fertig mit Speichern von 587
# Fertig mit Speichern von 588
# Fertig mit Speichern von 589
# Fertig mit Speichern von 590
# Fertig mit Speichern von 591
# Fertig mit Speichern von 592
# Fertig mit Speichern von 593
# Fertig mit Speichern von 594
# Fertig mit Speichern von 595
# Fertig mit Speichern von 596
# Fertig mit Speichern von 597
# Fertig mit Speichern von 598
# Fertig mit Speichern von 599
# Fertig mit Speichern von 600
# Fertig mit Speichern von 601
# Fertig mit Speichern von 602
# Fertig mit Speichern von 603
# Fertig mit Speichern von 604
# Fertig mit Speichern von 605
# Fertig mit Speichern von 606
# Fertig mit Speichern von 607
# Fertig mit Speichern von 608
# Fertig mit Speichern von 609
# Fertig mit Speichern von 610
# Fertig mit Speichern von 611
# Fertig mit Speichern von 612
# Fertig mit Speichern von 613
# Fertig mit Speichern von 614
# Fertig mit Speichern von 615
# Fertig mit Speichern von 616
# Fertig mit Speichern von 617
# Fertig mit Speichern von 618
# Fertig mit Speichern von 619
# Fertig mit Speichern von 620
# Fertig mit Speichern von 621
# Fertig mit Speichern von 622
# Fertig mit Speichern von 623
# Fertig mit Speichern von 624
# Fertig mit Speichern von 625
# Fertig mit Speichern von 626
# Fertig mit Speichern von 627
# Fertig mit Speichern von 628
# Fertig mit Speichern von 629
# Fertig mit Speichern von 630
# Fertig mit Speichern von 631
# Fertig mit Speichern von 632
# Fertig mit Speichern von 633
# Fertig mit Speichern von 634
# Fertig mit Speichern von 635
# Fertig mit Speichern von 636
# Fertig mit Speichern von 637
# Fertig mit Speichern von 638
# Fertig mit Speichern von 639
# Fertig mit Speichern von 640
# Fertig mit Speichern von 641
# Fertig mit Speichern von 642
# Fertig mit Speichern von 643
# Fertig mit Speichern von 644
# Fertig mit Speichern von 645
# Fertig mit Speichern von 646
# Fertig mit Speichern von 647
# Fertig mit Speichern von 648
# Fertig mit Speichern von 649
# Fertig mit Speichern von 650
# Fertig mit Speichern von 651
# Fertig mit Speichern von 652
# Fertig mit Speichern von 653
# Fertig mit Speichern von 654
# Fertig mit Speichern von 655
# Fertig mit Speichern von 656
# Fertig mit Speichern von 657
# Fertig mit Speichern von 658
# Fertig mit Speichern von 659
# Fertig mit Speichern von 660
# Fertig mit Speichern von 661
# Fertig mit Speichern von 662
# Fertig mit Speichern von 663
# Fertig mit Speichern von 664
# Fertig mit Speichern von 665
# Fertig mit Speichern von 666
# Fertig mit Speichern von 667
# Fertig mit Speichern von 668
# Fertig mit Speichern von 669
# Fertig mit Speichern von 670
# Fertig mit Speichern von 671
# Fertig mit Speichern von 672
# Fertig mit Speichern von 673
# Fertig mit Speichern von 674
# Fertig mit Speichern von 675
# Fertig mit Speichern von 676
# Fertig mit Speichern von 677
# Fertig mit Speichern von 678
# Fertig mit Speichern von 679
# Fertig mit Speichern von 680
# Fertig mit Speichern von 681
# Fertig mit Speichern von 682
# Fertig mit Speichern von 683
# Fertig mit Speichern von 684
# Fertig mit Speichern von 685
# Fertig mit Speichern von 686
# Fertig mit Speichern von 687
# Fertig mit Speichern von 688
# Fertig mit Speichern von 689
# Fertig mit Speichern von 690
# Fertig mit Speichern von 691
# Fertig mit Speichern von 692
# Fertig mit Speichern von 693
# Fertig mit Speichern von 694
# Fertig mit Speichern von 695
# Fertig mit Speichern von 696
# Fertig mit Speichern von 697
# Fertig mit Speichern von 698
# Fertig mit Speichern von 699
# Fertig mit Speichern von 700
# Fertig mit Speichern von 701
# Fertig mit Speichern von 702
# Fertig mit Speichern von 703
# Fertig mit Speichern von 704
# Fertig mit Speichern von 705
# Fertig mit Speichern von 706
# Fertig mit Speichern von 707
# Fertig mit Speichern von 708
# Fertig mit Speichern von 709
# Fertig mit Speichern von 710
# Fertig mit Speichern von 711
# Fertig mit Speichern von 712
# Fertig mit Speichern von 713
# Fertig mit Speichern von 714
# Fertig mit Speichern von 715
# Fertig mit Speichern von 716
# Fertig mit Speichern von 717
# Fertig mit Speichern von 718
# Fertig mit Speichern von 719
# Fertig mit Speichern von 720
# Fertig mit Speichern von 721
# Fertig mit Speichern von 722
# Fertig mit Speichern von 723
# Fertig mit Speichern von 724
# Fertig mit Speichern von 725
# Fertig mit Speichern von 726
# Fertig mit Speichern von 727
# Fertig mit Speichern von 728
# Fertig mit Speichern von 729
# Fertig mit Speichern von 730
# Fertig mit Speichern von 731
# Fertig mit Speichern von 732
# Fertig mit Speichern von 733
# Fertig mit Speichern von 734
# Fertig mit Speichern von 735
# Fertig mit Speichern von 736
# Fertig mit Speichern von 737
# Fertig mit Speichern von 738
# Fertig mit Speichern von 739
# Fertig mit Speichern von 740
# Fertig mit Speichern von 741
# Fertig mit Speichern von 742
# Fertig mit Speichern von 743
# Fertig mit Speichern von 744
# Fertig mit Speichern von 745
# Fertig mit Speichern von 746
# Fertig mit Speichern von 747
# Fertig mit Speichern von 748
# Fertig mit Speichern von 749
# Fertig mit Speichern von 750
# Fertig mit Speichern von 751
# Fertig mit Speichern von 752
# Fertig mit Speichern von 753
# Fertig mit Speichern von 754
# Fertig mit Speichern von 755
# Fertig mit Speichern von 756
# Fertig mit Speichern von 757
# Fertig mit Speichern von 758
# Fertig mit Speichern von 759
# Fertig mit Speichern von 760
# Fertig mit Speichern von 761
# Fertig mit Speichern von 762
# Fertig mit Speichern von 763
# Fertig mit Speichern von 764
# Fertig mit Speichern von 765
# Fertig mit Speichern von 766
# Fertig mit Speichern von 767
# Fertig mit Speichern von 768
# Fertig mit Speichern von 769
# Fertig mit Speichern von 770
# Fertig mit Speichern von 771
# Fertig mit Speichern von 772
# Fertig mit Speichern von 773
# Fertig mit Speichern von 774
# Fertig mit Speichern von 775
# Fertig mit Speichern von 776
# Fertig mit Speichern von 777
# Fertig mit Speichern von 778
# Fertig mit Speichern von 779
# Fertig mit Speichern von 780
# Fertig mit Speichern von 781
# Fertig mit Speichern von 782
# Fertig mit Speichern von 783
# Fertig mit Speichern von 784
# Fertig mit Speichern von 785
# Fertig mit Speichern von 786
# Fertig mit Speichern von 787
# Fertig mit Speichern von 788
# Fertig mit Speichern von 789
# Fertig mit Speichern von 790
# Fertig mit Speichern von 791
# Fertig mit Speichern von 792
# Fertig mit Speichern von 793
# Fertig mit Speichern von 794
# Fertig mit Speichern von 795
# Fertig mit Speichern von 796
# Fertig mit Speichern von 797
# Fertig mit Speichern von 798
# Fertig mit Speichern von 799
# Fertig mit Speichern von 800
# Fertig mit Speichern von 801
# Fertig mit Speichern von 802
# Fertig mit Speichern von 803
# Fertig mit Speichern von 804
# Fertig mit Speichern von 805
# Fertig mit Speichern von 806
# Fertig mit Speichern von 807
# Fertig mit Speichern von 808
# Fertig mit Speichern von 809
# Fertig mit Speichern von 810
# Fertig mit Speichern von 811
# Fertig mit Speichern von 812
# Fertig mit Speichern von 813
# Fertig mit Speichern von 814
# Fertig mit Speichern von 815
# Fertig mit Speichern von 816
# Fertig mit Speichern von 817
# Fertig mit Speichern von 818
# Fertig mit Speichern von 819
# Fertig mit Speichern von 820
# Fertig mit Speichern von 821
# Fertig mit Speichern von 822
# Fertig mit Speichern von 823
# Fertig mit Speichern von 824
# Fertig mit Speichern von 825
# Fertig mit Speichern von 826
# Fertig mit Speichern von 827
# Fertig mit Speichern von 828
# Fertig mit Speichern von 829
# Fertig mit Speichern von 830
# Fertig mit Speichern von 831
# Fertig mit Speichern von 832
# Fertig mit Speichern von 833
# Fertig mit Speichern von 834
# Fertig mit Speichern von 835
# Fertig mit Speichern von 836
# Fertig mit Speichern von 837
# Fertig mit Speichern von 838
# Fertig mit Speichern von 839
# Fertig mit Speichern von 840
# Fertig mit Speichern von 841
# Fertig mit Speichern von 842
# Fertig mit Speichern von 843
# Fertig mit Speichern von 844
# Fertig mit Speichern von 845
# Fertig mit Speichern von 846
# Fertig mit Speichern von 847
# Fertig mit Speichern von 848
# Fertig mit Speichern von 849
# Fertig mit Speichern von 850
# Fertig mit Speichern von 851
# Fertig mit Speichern von 852
# Fertig mit Speichern von 853
# Fertig mit Speichern von 854
# Fertig mit Speichern von 855
# Fertig mit Speichern von 856
# Fertig mit Speichern von 857
# Fertig mit Speichern von 858
# Fertig mit Speichern von 859
# Fertig mit Speichern von 860
# Fertig mit Speichern von 861
# Fertig mit Speichern von 862
# Fertig mit Speichern von 863
# Fertig mit Speichern von 864
# Fertig mit Speichern von 865
# Fertig mit Speichern von 866
# Fertig mit Speichern von 867
# Fertig mit Speichern von 868
# Fertig mit Speichern von 869
# Fertig mit Speichern von 870
# Fertig mit Speichern von 871
# Fertig mit Speichern von 872
# Fertig mit Speichern von 873
# Fertig mit Speichern von 874
# Fertig mit Speichern von 875
# Fertig mit Speichern von 876
# Fertig mit Speichern von 877
# Fertig mit Speichern von 878
# Fertig mit Speichern von 879
# Fertig mit Speichern von 880
# Fertig mit Speichern von 881
# Fertig mit Speichern von 882
# Fertig mit Speichern von 883
# Fertig mit Speichern von 884
# Fertig mit Speichern von 885
# Fertig mit Speichern von 886
# Fertig mit Speichern von 887
# Fertig mit Speichern von 888
# Fertig mit Speichern von 889
# Fertig mit Speichern von 890
# Fertig mit Speichern von 891
# Fertig mit Speichern von 892
# Fertig mit Speichern von 893
# Fertig mit Speichern von 894
# Fertig mit Speichern von 895
# Fertig mit Speichern von 896
# Fertig mit Speichern von 897
# Fertig mit Speichern von 898
# Fertig mit Speichern von 899
# Fertig mit Speichern von 900
# Fertig mit Speichern von 901
# Fertig mit Speichern von 902
# Fertig mit Speichern von 903
# Fertig mit Speichern von 904
# Fertig mit Speichern von 905
# Fertig mit Speichern von 906
# Fertig mit Speichern von 907
# Fertig mit Speichern von 908
# Fertig mit Speichern von 909
# Fertig mit Speichern von 910
# Fertig mit Speichern von 911
# Fertig mit Speichern von 912
# Fertig mit Speichern von 913
# Fertig mit Speichern von 914
# Fertig mit Speichern von 915
# Fertig mit Speichern von 916
# Fertig mit Speichern von 917
# Fertig mit Speichern von 918
# Fertig mit Speichern von 919
# Fertig mit Speichern von 920
# Fertig mit Speichern von 921
# Fertig mit Speichern von 922
# Fertig mit Speichern von 923
# Fertig mit Speichern von 924
# Fertig mit Speichern von 925
# Fertig mit Speichern von 926
# Fertig mit Speichern von 927
# Fertig mit Speichern von 928
# Fertig mit Speichern von 929
# Fertig mit Speichern von 930
# Fertig mit Speichern von 931
# Fertig mit Speichern von 932
# Fertig mit Speichern von 933
# Fertig mit Speichern von 934
# Fertig mit Speichern von 935
# Fertig mit Speichern von 936
# Fertig mit Speichern von 937
# Fertig mit Speichern von 938
# Fertig mit Speichern von 939
# Fertig mit Speichern von 940
# Fertig mit Speichern von 941
# Fertig mit Speichern von 942
# Fertig mit Speichern von 943
# Fertig mit Speichern von 944
# Fertig mit Speichern von 945
# Fertig mit Speichern von 946
# Fertig mit Speichern von 947
# Fertig mit Speichern von 948
# Fertig mit Speichern von 949
# Fertig mit Speichern von 950
# Fertig mit Speichern von 951
# Fertig mit Speichern von 952
# Fertig mit Speichern von 953
# Fertig mit Speichern von 954
# Fertig mit Speichern von 955
# Fertig mit Speichern von 956
# Fertig mit Speichern von 957
# Fertig mit Speichern von 958
# Fertig mit Speichern von 959
# Fertig mit Speichern von 960
# Fertig mit Speichern von 961
# Fertig mit Speichern von 962
# Fertig mit Speichern von 963
# Fertig mit Speichern von 964
# Fertig mit Speichern von 965
# Fertig mit Speichern von 966
# Fertig mit Speichern von 967
# Fertig mit Speichern von 968
# Fertig mit Speichern von 969
# Fertig mit Speichern von 970
# Fertig mit Speichern von 971
# Fertig mit Speichern von 972
# Fertig mit Speichern von 973
# Fertig mit Speichern von 974
# Fertig mit Speichern von 975
# Fertig mit Speichern von 976
# Fertig mit Speichern von 977
# Fertig mit Speichern von 978
# Fertig mit Speichern von 979
# Fertig mit Speichern von 980
# Fertig mit Speichern von 981
# Fertig mit Speichern von 982
# Fertig mit Speichern von 983
# Fertig mit Speichern von 984
# Fertig mit Speichern von 985
# Fertig mit Speichern von 986
# Fertig mit Speichern von 987
# Fertig mit Speichern von 988
# Fertig mit Speichern von 989
# Fertig mit Speichern von 990
# Fertig mit Speichern von 991
# Fertig mit Speichern von 992
# Fertig mit Speichern von 993
# Fertig mit Speichern von 994
# Fertig mit Speichern von 995
# Fertig mit Speichern von 996
# Fertig mit Speichern von 997
# Fertig mit Speichern von 998
# Fertig mit Speichern von 999
# Fertig mit Speichern von 1000
# Fertig mit Speichern von 1001
# Fertig mit Speichern von 1002
# Fertig mit Speichern von 1003
# Fertig mit Speichern von 1004
# Fertig mit Speichern von 1005
# Fertig mit Speichern von 1006
# Fertig mit Speichern von 1007
# Fertig mit Speichern von 1008
# Fertig mit Speichern von 1009
# Fertig mit Speichern von 1010
# Fertig mit Speichern von 1011
# Fertig mit Speichern von 1012
# Fertig mit Speichern von 1013
# Fertig mit Speichern von 1014
# Fertig mit Speichern von 1015
# Fertig mit Speichern von 1016
# Fertig mit Speichern von 1017
# Fertig mit Speichern von 1018
# Fertig mit Speichern von 1019
# Fertig mit Speichern von 1020
# Fertig mit Speichern von 1021
# Fertig mit Speichern von 1022
# Fertig mit Speichern von 1023
# Fertig mit Speichern von 1024
# Fertig mit Speichern von 1025
# Fertig mit Speichern von 1026
# Fertig mit Speichern von 1027
# Fertig mit Speichern von 1028
# Fertig mit Speichern von 1029
# Fertig mit Speichern von 1030
# Fertig mit Speichern von 1031
# Fertig mit Speichern von 1032
# Fertig mit Speichern von 1033
# Fertig mit Speichern von 1034
# Fertig mit Speichern von 1035
# Fertig mit Speichern von 1036
# Fertig mit Speichern von 1037
# Fertig mit Speichern von 1038
# Fertig mit Speichern von 1039
# Fertig mit Speichern von 1040
# Fertig mit Speichern von 1041
# Fertig mit Speichern von 1042
# Fertig mit Speichern von 1043
# Fertig mit Speichern von 1044
# Fertig mit Speichern von 1045
# Fertig mit Speichern von 1046
# Fertig mit Speichern von 1047
# Fertig mit Speichern von 1048
# Fertig mit Speichern von 1049
# Fertig mit Speichern von 1050
# Fertig mit Speichern von 1051
# Fertig mit Speichern von 1052
# Fertig mit Speichern von 1053
# Fertig mit Speichern von 1054
# Fertig mit Speichern von 1055
# Fertig mit Speichern von 1056
# Fertig mit Speichern von 1057
# Fertig mit Speichern von 1058
# Fertig mit Speichern von 1059
# Fertig mit Speichern von 1060
# Fertig mit Speichern von 1061
# Fertig mit Speichern von 1062
# Fertig mit Speichern von 1063
# Fertig mit Speichern von 1064
# Fertig mit Speichern von 1065
# Fertig mit Speichern von 1066
# Fertig mit Speichern von 1067
# Fertig mit Speichern von 1068
# Fertig mit Speichern von 1069
# Fertig mit Speichern von 1070
# Fertig mit Speichern von 1071
# Fertig mit Speichern von 1072
# Fertig mit Speichern von 1073
# Fertig mit Speichern von 1074
# Fertig mit Speichern von 1075
# Fertig mit Speichern von 1076
# Fertig mit Speichern von 1077
# Fertig mit Speichern von 1078
# Fertig mit Speichern von 1079
# Fertig mit Speichern von 1080
# Fertig mit Speichern von 1081
# Fertig mit Speichern von 1082
# Fertig mit Speichern von 1083
# Fertig mit Speichern von 1084
# Fertig mit Speichern von 1085
# Fertig mit Speichern von 1086
# Fertig mit Speichern von 1087
# Fertig mit Speichern von 1088
# Fertig mit Speichern von 1089
# Fertig mit Speichern von 1090
# Fertig mit Speichern von 1091
# Fertig mit Speichern von 1092
# Fertig mit Speichern von 1093
# Fertig mit Speichern von 1094
# Fertig mit Speichern von 1095
# Fertig mit Speichern von 1096
# Fertig mit Speichern von 1097
# Fertig mit Speichern von 1098
# Fertig mit Speichern von 1099
# Fertig mit Speichern von 1100
# Fertig mit Speichern von 1101
# Fertig mit Speichern von 1102
# Fertig mit Speichern von 1103
# Fertig mit Speichern von 1104
# Fertig mit Speichern von 1105
# Fertig mit Speichern von 1106
# Fertig mit Speichern von 1107
# Fertig mit Speichern von 1108
# Fertig mit Speichern von 1109
# Fertig mit Speichern von 1110
# Fertig mit Speichern von 1111
# Fertig mit Speichern von 1112
# Fertig mit Speichern von 1113
# Fertig mit Speichern von 1114
# Fertig mit Speichern von 1115
# Fertig mit Speichern von 1116
# Fertig mit Speichern von 1117
# Fertig mit Speichern von 1118
# Fertig mit Speichern von 1119
# Fertig mit Speichern von 1120
# Fertig mit Speichern von 1121
# Fertig mit Speichern von 1122
# Fertig mit Speichern von 1123
# Fertig mit Speichern von 1124
# Fertig mit Speichern von 1125
# Fertig mit Speichern von 1126
# Fertig mit Speichern von 1127
# Fertig mit Speichern von 1128
# Fertig mit Speichern von 1129
# Fertig mit Speichern von 1130
# Fertig mit Speichern von 1131
# Fertig mit Speichern von 1132
# Fertig mit Speichern von 1133
# Fertig mit Speichern von 1134
# Fertig mit Speichern von 1135
# Fertig mit Speichern von 1136
# Fertig mit Speichern von 1137
# Fertig mit Speichern von 1138
# Fertig mit Speichern von 1139
# Fertig mit Speichern von 1140
# Fertig mit Speichern von 1141
# Fertig mit Speichern von 1142
# Fertig mit Speichern von 1143
# Fertig mit Speichern von 1144
# Fertig mit Speichern von 1145
# Fertig mit Speichern von 1146
# Fertig mit Speichern von 1147
# Fertig mit Speichern von 1148
# Fertig mit Speichern von 1149
# Fertig mit Speichern von 1150
# Fertig mit Speichern von 1151
# Fertig mit Speichern von 1152
# Fertig mit Speichern von 1153
# Fertig mit Speichern von 1154
# Fertig mit Speichern von 1155
# Fertig mit Speichern von 1156
# Fertig mit Speichern von 1157
# Fertig mit Speichern von 1158
# Fertig mit Speichern von 1159
# Fertig mit Speichern von 1160
# Fertig mit Speichern von 1161
# Fertig mit Speichern von 1162
# Fertig mit Speichern von 1163
# Fertig mit Speichern von 1164
# Fertig mit Speichern von 1165
# Fertig mit Speichern von 1166
# Fertig mit Speichern von 1167
# Fertig mit Speichern von 1168
# Fertig mit Speichern von 1169
# Fertig mit Speichern von 1170
# Fertig mit Speichern von 1171
# Fertig mit Speichern von 1172
# Fertig mit Speichern von 1173
# Fertig mit Speichern von 1174
# Fertig mit Speichern von 1175
# Fertig mit Speichern von 1176
# Fertig mit Speichern von 1177
# Fertig mit Speichern von 1178
# Fertig mit Speichern von 1179
# Fertig mit Speichern von 1180
# Fertig mit Speichern von 1181
# Fertig mit Speichern von 1182
# Fertig mit Speichern von 1183
# Fertig mit Speichern von 1184
# Fertig mit Speichern von 1185
# Fertig mit Speichern von 1186
# Fertig mit Speichern von 1187
# Fertig mit Speichern von 1188
# Fertig mit Speichern von 1189
# Fertig mit Speichern von 1190
# Fertig mit Speichern von 1191
# Fertig mit Speichern von 1192
# Fertig mit Speichern von 1193
# Fertig mit Speichern von 1194
# Fertig mit Speichern von 1195
# Fertig mit Speichern von 1196
# Fertig mit Speichern von 1197
# Fertig mit Speichern von 1198
# Fertig mit Speichern von 1199
# Fertig mit Speichern von 1200
# Fertig mit Speichern von 1201
# Fertig mit Speichern von 1202
# Fertig mit Speichern von 1203
# Fertig mit Speichern von 1204
# Fertig mit Speichern von 1205
# Fertig mit Speichern von 1206
# Fertig mit Speichern von 1207
# Fertig mit Speichern von 1208
# Fertig mit Speichern von 1209
# Fertig mit Speichern von 1210
# Fertig mit Speichern von 1211
# Fertig mit Speichern von 1212
# Fertig mit Speichern von 1213
# Fertig mit Speichern von 1214
# Fertig mit Speichern von 1215
# Fertig mit Speichern von 1216
# Fertig mit Speichern von 1217
# Fertig mit Speichern von 1218
# Fertig mit Speichern von 1219
# Fertig mit Speichern von 1220
# Fertig mit Speichern von 1221
# Fertig mit Speichern von 1222
# Fertig mit Speichern von 1223
# Fertig mit Speichern von 1224
# Fertig mit Speichern von 1225
# Fertig mit Speichern von 1226
# Fertig mit Speichern von 1227
# Fertig mit Speichern von 1228
# Fertig mit Speichern von 1229
# Fertig mit Speichern von 1230
# Fertig mit Speichern von 1231
# Fertig mit Speichern von 1232
# Fertig mit Speichern von 1233
# Fertig mit Speichern von 1234
# Fertig mit Speichern von 1235
# Fertig mit Speichern von 1236
# Fertig mit Speichern von 1237
# Fertig mit Speichern von 1238
# Fertig mit Speichern von 1239
# Fertig mit Speichern von 1240
# Fertig mit Speichern von 1241
# Fertig mit Speichern von 1242
# Fertig mit Speichern von 1243
# Fertig mit Speichern von 1244
# Fertig mit Speichern von 1245
# Fertig mit Speichern von 1246
# Fertig mit Speichern von 1247
# Fertig mit Speichern von 1248
# Fertig mit Speichern von 1249
# Fertig mit Speichern von 1250
# Fertig mit Speichern von 1251
# Fertig mit Speichern von 1252
# Fertig mit Speichern von 1253
# Fertig mit Speichern von 1254
# Fertig mit Speichern von 1255
# Fertig mit Speichern von 1256
# Fertig mit Speichern von 1257
# Fertig mit Speichern von 1258
# Fertig mit Speichern von 1259
# Fertig mit Speichern von 1260
# Fertig mit Speichern von 1261
# Fertig mit Speichern von 1262
# Fertig mit Speichern von 1263
# Fertig mit Speichern von 1264
# Fertig mit Speichern von 1265
# Fertig mit Speichern von 1266
# Fertig mit Speichern von 1267
# Fertig mit Speichern von 1268
# Fertig mit Speichern von 1269
# Fertig mit Speichern von 1270
# Fertig mit Speichern von 1271
# Fertig mit Speichern von 1272
# Fertig mit Speichern von 1273
# Fertig mit Speichern von 1274
# Fertig mit Speichern von 1275
# Fertig mit Speichern von 1276
# Fertig mit Speichern von 1277
# Fertig mit Speichern von 1278
# Fertig mit Speichern von 1279
# Fertig mit Speichern von 1280
# Fertig mit Speichern von 1281
# Fertig mit Speichern von 1282
# Fertig mit Speichern von 1283
# Fertig mit Speichern von 1284
# Fertig mit Speichern von 1285
# Fertig mit Speichern von 1286
# Fertig mit Speichern von 1287
# Fertig mit Speichern von 1288
# Fertig mit Speichern von 1289
# Fertig mit Speichern von 1290
# Fertig mit Speichern von 1291
# Fertig mit Speichern von 1292
# Fertig mit Speichern von 1293
# Fertig mit Speichern von 1294
# Fertig mit Speichern von 1295
# Fertig mit Speichern von 1296
# Fertig mit Speichern von 1297
# Fertig mit Speichern von 1298
# Fertig mit Speichern von 1299
# Fertig mit Speichern von 1300
# Fertig mit Speichern von 1301
# Fertig mit Speichern von 1302
# Fertig mit Speichern von 1303
# Fertig mit Speichern von 1304
# Fertig mit Speichern von 1305
# Fertig mit Speichern von 1306
# Fertig mit Speichern von 1307
# Fertig mit Speichern von 1308
# Fertig mit Speichern von 1309
# Fertig mit Speichern von 1310
# Fertig mit Speichern von 1311
# Fertig mit Speichern von 1312
# Fertig mit Speichern von 1313
# Fertig mit Speichern von 1314
# Fertig mit Speichern von 1315
# Fertig mit Speichern von 1316
# Fertig mit Speichern von 1317
# Fertig mit Speichern von 1318
# Fertig mit Speichern von 1319
# Fertig mit Speichern von 1320
# Fertig mit Speichern von 1321
# Fertig mit Speichern von 1322
# Fertig mit Speichern von 1323
# Fertig mit Speichern von 1324
# Fertig mit Speichern von 1325
# Fertig mit Speichern von 1326
# Fertig mit Speichern von 1327
# Fertig mit Speichern von 1328
# Fertig mit Speichern von 1329
# Fertig mit Speichern von 1330
# Fertig mit Speichern von 1331
# Fertig mit Speichern von 1332
# Fertig mit Speichern von 1333
# Fertig mit Speichern von 1334
# Fertig mit Speichern von 1335
# Fertig mit Speichern von 1336
# Fertig mit Speichern von 1337
# Fertig mit Speichern von 1338
# Fertig mit Speichern von 1339
# Fertig mit Speichern von 1340
# Fertig mit Speichern von 1341
# Fertig mit Speichern von 1342
# Fertig mit Speichern von 1343
# Fertig mit Speichern von 1344
# Fertig mit Speichern von 1345
# Fertig mit Speichern von 1346
# Fertig mit Speichern von 1347
# Fertig mit Speichern von 1348
# Fertig mit Speichern von 1349
# Fertig mit Speichern von 1350
# Fertig mit Speichern von 1351
# Fertig mit Speichern von 1352
# Fertig mit Speichern von 1353
# Fertig mit Speichern von 1354
# Fertig mit Speichern von 1355
# Fertig mit Speichern von 1356
# Fertig mit Speichern von 1357
# Fertig mit Speichern von 1358
# Fertig mit Speichern von 1359
# Fertig mit Speichern von 1360
# Fertig mit Speichern von 1361
# Fertig mit Speichern von 1362
# Fertig mit Speichern von 1363
# Fertig mit Speichern von 1364
# Fertig mit Speichern von 1365
# Fertig mit Speichern von 1366
# Fertig mit Speichern von 1367
# Fertig mit Speichern von 1368
# Fertig mit Speichern von 1369
# Fertig mit Speichern von 1370
# Fertig mit Speichern von 1371
# Fertig mit Speichern von 1372
# Fertig mit Speichern von 1373
# Fertig mit Speichern von 1374
# Fertig mit Speichern von 1375
# Fertig mit Speichern von 1376
# Fertig mit Speichern von 1377
# Fertig mit Speichern von 1378
# Fertig mit Speichern von 1379
# Fertig mit Speichern von 1380
# Fertig mit Speichern von 1381
# Fertig mit Speichern von 1382
# Fertig mit Speichern von 1383
# Fertig mit Speichern von 1384
# Fertig mit Speichern von 1385
# Fertig mit Speichern von 1386
# Fertig mit Speichern von 1387
# Fertig mit Speichern von 1388
# Fertig mit Speichern von 1389
# Fertig mit Speichern von 1390
# Fertig mit Speichern von 1391
# Fertig mit Speichern von 1392
# Fertig mit Speichern von 1393
# Fertig mit Speichern von 1394
# Fertig mit Speichern von 1395
# Fertig mit Speichern von 1396
# Fertig mit Speichern von 1397
# Fertig mit Speichern von 1398
# Fertig mit Speichern von 1399
# Fertig mit Speichern von 1400
# Fertig mit Speichern von 1401
# Fertig mit Speichern von 1402
# Fertig mit Speichern von 1403
# Fertig mit Speichern von 1404
# Fertig mit Speichern von 1405
# Fertig mit Speichern von 1406
# Fertig mit Speichern von 1407
# Fertig mit Speichern von 1408
# Fertig mit Speichern von 1409
# Fertig mit Speichern von 1410
# Fertig mit Speichern von 1411
# Fertig mit Speichern von 1412
# Fertig mit Speichern von 1413
# Fertig mit Speichern von 1414
# Fertig mit Speichern von 1415
# Fertig mit Speichern von 1416
# Fertig mit Speichern von 1417
# Fertig mit Speichern von 1418
# Fertig mit Speichern von 1419
# Fertig mit Speichern von 1420
# Fertig mit Speichern von 1421
# Fertig mit Speichern von 1422
# Fertig mit Speichern von 1423
# Fertig mit Speichern von 1424
# Fertig mit Speichern von 1425
# Fertig mit Speichern von 1426
# Fertig mit Speichern von 1427
# Fertig mit Speichern von 1428
# Fertig mit Speichern von 1429
# Fertig mit Speichern von 1430
# Fertig mit Speichern von 1431
# Fertig mit Speichern von 1432
# Fertig mit Speichern von 1433
# Fertig mit Speichern von 1434
# Fertig mit Speichern von 1435
# Fertig mit Speichern von 1436
# Fertig mit Speichern von 1437
# Fertig mit Speichern von 1438
# Fertig mit Speichern von 1439
# Fertig mit Speichern von 1440
# Fertig mit Speichern von 1441
# Fertig mit Speichern von 1442
# Fertig mit Speichern von 1443
# Fertig mit Speichern von 1444
# Fertig mit Speichern von 1445
# Fertig mit Speichern von 1446
# Fertig mit Speichern von 1447
# Fertig mit Speichern von 1448
# Fertig mit Speichern von 1449
# Fertig mit Speichern von 1450
# Fertig mit Speichern von 1451
# Fertig mit Speichern von 1452
# Fertig mit Speichern von 1453
# Fertig mit Speichern von 1454
# Fertig mit Speichern von 1455
# Fertig mit Speichern von 1456
# Fertig mit Speichern von 1457
# Fertig mit Speichern von 1458
# Fertig mit Speichern von 1459
# Fertig mit Speichern von 1460
# Fertig mit Speichern von 1461
# Fertig mit Speichern von 1462
# Fertig mit Speichern von 1463
# Fertig mit Speichern von 1464
# Fertig mit Speichern von 1465
# Fertig mit Speichern von 1466
# Fertig mit Speichern von 1467
# Fertig mit Speichern von 1468
# Fertig mit Speichern von 1469
# Fertig mit Speichern von 1470
# Fertig mit Speichern von 1471
# Fertig mit Speichern von 1472
# Fertig mit Speichern von 1473
# Fertig mit Speichern von 1474
# Fertig mit Speichern von 1475
# Fertig mit Speichern von 1476
# Fertig mit Speichern von 1477
# Fertig mit Speichern von 1478
# Fertig mit Speichern von 1479
# Fertig mit Speichern von 1480
# Fertig mit Speichern von 1481
# Fertig mit Speichern von 1482
# Fertig mit Speichern von 1483
# Fertig mit Speichern von 1484
# Fertig mit Speichern von 1485
# Fertig mit Speichern von 1486
# Fertig mit Speichern von 1487
# Fertig mit Speichern von 1488
# Fertig mit Speichern von 1489
# Fertig mit Speichern von 1490
# Fertig mit Speichern von 1491
# Fertig mit Speichern von 1492
# Fertig mit Speichern von 1493
# Fertig mit Speichern von 1494
# Fertig mit Speichern von 1495
# Fertig mit Speichern von 1496
# Fertig mit Speichern von 1497
# Fertig mit Speichern von 1498
# Fertig mit Speichern von 1499
# Fertig mit Speichern von 1500
# Fertig mit Speichern von 1501
# Fertig mit Speichern von 1502
# Fertig mit Speichern von 1503
# Fertig mit Speichern von 1504
# Fertig mit Speichern von 1505
# Fertig mit Speichern von 1506
# Fertig mit Speichern von 1507
# Fertig mit Speichern von 1508
# Fertig mit Speichern von 1509
# Fertig mit Speichern von 1510
# Fertig mit Speichern von 1511
# Fertig mit Speichern von 1512
# Fertig mit Speichern von 1513
# Fertig mit Speichern von 1514
# Fertig mit Speichern von 1515
# Fertig mit Speichern von 1516
# Fertig mit Speichern von 1517
# Fertig mit Speichern von 1518
# Fertig mit Speichern von 1519
# Fertig mit Speichern von 1520
# Fertig mit Speichern von 1521
# Fertig mit Speichern von 1522
# Fertig mit Speichern von 1523
# Fertig mit Speichern von 1524
# Fertig mit Speichern von 1525
# Fertig mit Speichern von 1526
# Fertig mit Speichern von 1527
# Fertig mit Speichern von 1528
# Fertig mit Speichern von 1529
# Fertig mit Speichern von 1530
# Fertig mit Speichern von 1531
# Fertig mit Speichern von 1532
# Fertig mit Speichern von 1533
# Fertig mit Speichern von 1534
# Fertig mit Speichern von 1535
# Fertig mit Speichern von 1536
# Fertig mit Speichern von 1537
# Fertig mit Speichern von 1538
# Fertig mit Speichern von 1539
# Fertig mit Speichern von 1540
# Fertig mit Speichern von 1541
# Fertig mit Speichern von 1542
# Fertig mit Speichern von 1543
# Fertig mit Speichern von 1544
# Fertig mit Speichern von 1545
# Fertig mit Speichern von 1546
# Fertig mit Speichern von 1547
# Fertig mit Speichern von 1548
# Fertig mit Speichern von 1549
# Fertig mit Speichern von 1550
# Fertig mit Speichern von 1551
# Fertig mit Speichern von 1552
# Fertig mit Speichern von 1553
# Fertig mit Speichern von 1554
# Fertig mit Speichern von 1555
# Fertig mit Speichern von 1556
# Fertig mit Speichern von 1557
# Fertig mit Speichern von 1558
# Fertig mit Speichern von 1559
# Fertig mit Speichern von 1560
# Fertig mit Speichern von 1561
# Fertig mit Speichern von 1562
# Fertig mit Speichern von 1563
# Fertig mit Speichern von 1564
# Fertig mit Speichern von 1565
# Fertig mit Speichern von 1566
# Fertig mit Speichern von 1567
# Fertig mit Speichern von 1568
# Fertig mit Speichern von 1569
# Fertig mit Speichern von 1570
# Fertig mit Speichern von 1571
# Fertig mit Speichern von 1572
# Fertig mit Speichern von 1573
# Fertig mit Speichern von 1574
# Fertig mit Speichern von 1575
# Fertig mit Speichern von 1576
# Fertig mit Speichern von 1577
# Fertig mit Speichern von 1578
# Fertig mit Speichern von 1579
# Fertig mit Speichern von 1580
# Fertig mit Speichern von 1581
# Fertig mit Speichern von 1582
# Fertig mit Speichern von 1583
# Fertig mit Speichern von 1584
# Fertig mit Speichern von 1585
# Fertig mit Speichern von 1586
# Fertig mit Speichern von 1587
# Fertig mit Speichern von 1588
# Fertig mit Speichern von 1589
# Fertig mit Speichern von 1590
# Fertig mit Speichern von 1591
# Fertig mit Speichern von 1592
# Fertig mit Speichern von 1593
# Fertig mit Speichern von 1594
# Fertig mit Speichern von 1595
# Fertig mit Speichern von 1596
# Fertig mit Speichern von 1597
# Fertig mit Speichern von 1598
# Fertig mit Speichern von 1599
# Fertig mit Speichern von 1600
# Fertig mit Speichern von 1601
# Fertig mit Speichern von 1602
# Fertig mit Speichern von 1603
# Fertig mit Speichern von 1604
# Fertig mit Speichern von 1605
# Fertig mit Speichern von 1606
# Fertig mit Speichern von 1607
# Fertig mit Speichern von 1608
# Fertig mit Speichern von 1609
# Fertig mit Speichern von 1610
# Fertig mit Speichern von 1611
# Fertig mit Speichern von 1612
# Fertig mit Speichern von 1613
# Fertig mit Speichern von 1614
# Fertig mit Speichern von 1615
# Fertig mit Speichern von 1616
# Fertig mit Speichern von 1617
# Fertig mit Speichern von 1618
# Fertig mit Speichern von 1619
# Fertig mit Speichern von 1620
# Fertig mit Speichern von 1621
# Fertig mit Speichern von 1622
# Fertig mit Speichern von 1623
# Fertig mit Speichern von 1624
# Fertig mit Speichern von 1625
# Fertig mit Speichern von 1626
# Fertig mit Speichern von 1627
# Fertig mit Speichern von 1628
# Fertig mit Speichern von 1629
# Fertig mit Speichern von 1630
# Fertig mit Speichern von 1631
# Fertig mit Speichern von 1632
# Fertig mit Speichern von 1633
# ...
# Fertig mit Speichern von 32439
# Fertig mit Speichern von 32440
# Fertig mit Speichern von 32441
# Fertig mit Speichern von 32442
# Fertig mit Speichern von 32443
# Fertig mit Speichern von 32444
# Fertig mit Speichern von 32445
# Fertig mit Speichern von 32446
# Fertig mit Speichern von 32447
# Fertig mit Speichern von 32448
# Fertig mit Speichern von 32449
# Fertig mit Speichern von 32450
# Fertig mit Speichern von 32451
# Fertig mit Speichern von 32452
# Fertig mit Speichern von 32453
# Fertig mit Speichern von 32454
# Fertig mit Speichern von 32455
# Fertig mit Speichern von 32456
# Fertig mit Speichern von 32457
# Fertig mit Speichern von 32458
# Fertig mit Speichern von 32459
# Fertig mit Speichern von 32460
# Fertig mit Speichern von 32461
# Fertig mit Speichern von 32462
# Fertig mit Speichern von 32463
# Fertig mit Speichern von 32464
# Fertig mit Speichern von 32465
# Fertig mit Speichern von 32466
# Fertig mit Speichern von 32467
# Fertig mit Speichern von 32468
# Fertig mit Speichern von 32469
# Fertig mit Speichern von 32470
# Fertig mit Speichern von 32471
# Fertig mit Speichern von 32472
# Fertig mit Speichern von 32473
# Fertig mit Speichern von 32474
# Fertig mit Speichern von 32475
# Fertig mit Speichern von 32476
# Fertig mit Speichern von 32477
# Fertig mit Speichern von 32478
# Fertig mit Speichern von 32479
# Fertig mit Speichern von 32480
# Fertig mit Speichern von 32481
# Fertig mit Speichern von 32482
# Fertig mit Speichern von 32483
# Fertig mit Speichern von 32484
# Fertig mit Speichern von 32485
# Fertig mit Speichern von 32486
# Fertig mit Speichern von 32487
# Fertig mit Speichern von 32488
# Fertig mit Speichern von 32489
# Fertig mit Speichern von 32490
# Fertig mit Speichern von 32491
# Fertig mit Speichern von 32492
# Fertig mit Speichern von 32493
# Fertig mit Speichern von 32494
# Fertig mit Speichern von 32495
# Fertig mit Speichern von 32496
# Fertig mit Speichern von 32497
# Fertig mit Speichern von 32498
# Fertig mit Speichern von 32499
# Fertig mit Speichern von 32500
# Fertig mit Speichern von 32501
# Fertig mit Speichern von 32502
# Fertig mit Speichern von 32503
# Fertig mit Speichern von 32504
# Fertig mit Speichern von 32505
# Fertig mit Speichern von 32506
# Fertig mit Speichern von 32507
# Fertig mit Speichern von 32508
# Fertig mit Speichern von 32509
# Fertig mit Speichern von 32510
# Fertig mit Speichern von 32511
# Fertig mit Speichern von 32512
# Fertig mit Speichern von 32513
# Fertig mit Speichern von 32514
# Fertig mit Speichern von 32515
# Fertig mit Speichern von 32516
# Fertig mit Speichern von 32517
# Fertig mit Speichern von 32518
# Fertig mit Speichern von 32519
# Fertig mit Speichern von 32520
# Fertig mit Speichern von 32521
# Fertig mit Speichern von 32522
# Fertig mit Speichern von 32523
# Fertig mit Speichern von 32524
# Fertig mit Speichern von 32525
# Fertig mit Speichern von 32526
# Fertig mit Speichern von 32527
# Fertig mit Speichern von 32528
# Fertig mit Speichern von 32529
# Fertig mit Speichern von 32530
# Fertig mit Speichern von 32531
# Fertig mit Speichern von 32532
# Fertig mit Speichern von 32533
# Fertig mit Speichern von 32534
# Fertig mit Speichern von 32535
# Fertig mit Speichern von 32536
# Fertig mit Speichern von 32537
# Fertig mit Speichern von 32538
# Fertig mit Speichern von 32539
# Fertig mit Speichern von 32540
# Fertig mit Speichern von 32541
# Fertig mit Speichern von 32542
# Fertig mit Speichern von 32543
# Fertig mit Speichern von 32544
# Fertig mit Speichern von 32545
# Fertig mit Speichern von 32546
# Fertig mit Speichern von 32547
# Fertig mit Speichern von 32548
# Fertig mit Speichern von 32549
# Fertig mit Speichern von 32550
# Fertig mit Speichern von 32551
# Fertig mit Speichern von 32552
# Fertig mit Speichern von 32553
# Fertig mit Speichern von 32554
# Fertig mit Speichern von 32555
# Fertig mit Speichern von 32556
# Fertig mit Speichern von 32557
# Fertig mit Speichern von 32558
# Fertig mit Speichern von 32559
# Fertig mit Speichern von 32560
# Fertig mit Speichern von 32561
# Fertig mit Speichern von 32562
# Fertig mit Speichern von 32563
# Fertig mit Speichern von 32564
# Fertig mit Speichern von 32565
# Fertig mit Speichern von 32566
# Fertig mit Speichern von 32567
# Fertig mit Speichern von 32568
# Fertig mit Speichern von 32569
# Fertig mit Speichern von 32570
# Fertig mit Speichern von 32571
# Fertig mit Speichern von 32572
# Fertig mit Speichern von 32573
# Fertig mit Speichern von 32574
# Fertig mit Speichern von 32575
# Fertig mit Speichern von 32576
# Fertig mit Speichern von 32577
# Fertig mit Speichern von 32578
# Fertig mit Speichern von 32579
# Fertig mit Speichern von 32580
# Fertig mit Speichern von 32581
# Fertig mit Speichern von 32582
# Fertig mit Speichern von 32583
# Fertig mit Speichern von 32584
# Fertig mit Speichern von 32585
# Fertig mit Speichern von 32586
# Fertig mit Speichern von 32587
# Fertig mit Speichern von 32588
# Fertig mit Speichern von 32589
# Fertig mit Speichern von 32590
# Fertig mit Speichern von 32591
# Fertig mit Speichern von 32592
# Fertig mit Speichern von 32593
# Fertig mit Speichern von 32594
# Fertig mit Speichern von 32595
# Fertig mit Speichern von 32596
# Fertig mit Speichern von 32597
# Fertig mit Speichern von 32598
# Fertig mit Speichern von 32599
# Fertig mit Speichern von 32600
# Fertig mit Speichern von 32601
# Fertig mit Speichern von 32602
# Fertig mit Speichern von 32603
# Fertig mit Speichern von 32604
# Fertig mit Speichern von 32605
# Fertig mit Speichern von 32606
# Fertig mit Speichern von 32607
# Fertig mit Speichern von 32608
# Fertig mit Speichern von 32609
# Fertig mit Speichern von 32610
# Fertig mit Speichern von 32611
# Fertig mit Speichern von 32612
# Fertig mit Speichern von 32613
# Fertig mit Speichern von 32614
# Fertig mit Speichern von 32615
# Fertig mit Speichern von 32616
# Fertig mit Speichern von 32617
# Fertig mit Speichern von 32618
# Fertig mit Speichern von 32619
# Fertig mit Speichern von 32620
# Fertig mit Speichern von 32621
# Fertig mit Speichern von 32622
# Fertig mit Speichern von 32623
# Fertig mit Speichern von 32624
# Fertig mit Speichern von 32625
# Fertig mit Speichern von 32626
# Fertig mit Speichern von 32627
# Fertig mit Speichern von 32628
# Fertig mit Speichern von 32629
# Fertig mit Speichern von 32630
# Fertig mit Speichern von 32631
# Fertig mit Speichern von 32632
# Fertig mit Speichern von 32633
# Fertig mit Speichern von 32634
# Fertig mit Speichern von 32635
# Fertig mit Speichern von 32636
# Fertig mit Speichern von 32637
# Fertig mit Speichern von 32638
# Fertig mit Speichern von 32639
# Fertig mit Speichern von 32640
# Fertig mit Speichern von 32641
# Fertig mit Speichern von 32642
# Fertig mit Speichern von 32643
# Fertig mit Speichern von 32644
# Fertig mit Speichern von 32645
# Fertig mit Speichern von 32646
# Fertig mit Speichern von 32647
# Fertig mit Speichern von 32648
# Fertig mit Speichern von 32649
# Fertig mit Speichern von 32650
# Fertig mit Speichern von 32651
# Fertig mit Speichern von 32652
# Fertig mit Speichern von 32653
# Fertig mit Speichern von 32654
# Fertig mit Speichern von 32655
# Fertig mit Speichern von 32656
# Fertig mit Speichern von 32657
# Fertig mit Speichern von 32658
# Fertig mit Speichern von 32659
# Fertig mit Speichern von 32660
# Fertig mit Speichern von 32661
# Fertig mit Speichern von 32662
# Fertig mit Speichern von 32663
# Fertig mit Speichern von 32664
# Fertig mit Speichern von 32665
# Fertig mit Speichern von 32666
# Fertig mit Speichern von 32667
# Fertig mit Speichern von 32668
# Fertig mit Speichern von 32669
# Fertig mit Speichern von 32670
# Fertig mit Speichern von 32671
# Fertig mit Speichern von 32672
# Fertig mit Speichern von 32673
# Fertig mit Speichern von 32674
# Fertig mit Speichern von 32675
# Fertig mit Speichern von 32676
# Fertig mit Speichern von 32677
# Fertig mit Speichern von 32678
# Fertig mit Speichern von 32679
# Fertig mit Speichern von 32680
# Fertig mit Speichern von 32681
# Fertig mit Speichern von 32682
# Fertig mit Speichern von 32683
# Fertig mit Speichern von 32684
# Fertig mit Speichern von 32685
# Fertig mit Speichern von 32686
# Fertig mit Speichern von 32687
# Fertig mit Speichern von 32688
# Fertig mit Speichern von 32689
# Fertig mit Speichern von 32690
# Fertig mit Speichern von 32691
# Fertig mit Speichern von 32692
# Fertig mit Speichern von 32693
# Fertig mit Speichern von 32694
# Fertig mit Speichern von 32695
# Fertig mit Speichern von 32696
# Fertig mit Speichern von 32697
# Fertig mit Speichern von 32698
# Fertig mit Speichern von 32699
# Fertig mit Speichern von 32700
# Fertig mit Speichern von 32701
# Fertig mit Speichern von 32702
# Fertig mit Speichern von 32703
# Fertig mit Speichern von 32704
# Fertig mit Speichern von 32705
# Fertig mit Speichern von 32706
# Fertig mit Speichern von 32707
# Fertig mit Speichern von 32708
# Fertig mit Speichern von 32709
# Fertig mit Speichern von 32710
# Fertig mit Speichern von 32711
# Fertig mit Speichern von 32712
# Fertig mit Speichern von 32713
# Fertig mit Speichern von 32714
# Fertig mit Speichern von 32715
# Fertig mit Speichern von 32716
# Fertig mit Speichern von 32717
# Fertig mit Speichern von 32718
# Fertig mit Speichern von 32719
# Fertig mit Speichern von 32720
# Fertig mit Speichern von 32721
# Fertig mit Speichern von 32722
# Fertig mit Speichern von 32723
# Fertig mit Speichern von 32724
# Fertig mit Speichern von 32725
# Fertig mit Speichern von 32726
# Fertig mit Speichern von 32727
# Fertig mit Speichern von 32728
# Fertig mit Speichern von 32729
# Fertig mit Speichern von 32730
# Fertig mit Speichern von 32731
# Fertig mit Speichern von 32732
# Fertig mit Speichern von 32733
# Fertig mit Speichern von 32734
# Fertig mit Speichern von 32735
# Fertig mit Speichern von 32736
# Fertig mit Speichern von 32737
# Fertig mit Speichern von 32738
# Fertig mit Speichern von 32739
# Fertig mit Speichern von 32740
# Fertig mit Speichern von 32741
# Fertig mit Speichern von 32742
# Fertig mit Speichern von 32743
# Fertig mit Speichern von 32744
# Fertig mit Speichern von 32745
# Fertig mit Speichern von 32746
# Fertig mit Speichern von 32747
# Fertig mit Speichern von 32748
# Fertig mit Speichern von 32749
# Fertig mit Speichern von 32750
# Fertig mit Speichern von 32751
# Fertig mit Speichern von 32752
# Fertig mit Speichern von 32753
# Fertig mit Speichern von 32754
# Fertig mit Speichern von 32755
# Fertig mit Speichern von 32756
# Fertig mit Speichern von 32757
# Fertig mit Speichern von 32758
# Fertig mit Speichern von 32759
# Fertig mit Speichern von 32760
# Fertig mit Speichern von 32761
# Fertig mit Speichern von 32762
# Fertig mit Speichern von 32763
# Fertig mit Speichern von 32764
# Fertig mit Speichern von 32765
# Fertig mit Speichern von 32766
# Fertig mit Speichern von 32767
# Fertig mit Speichern von 32768
# Fertig mit Speichern von 32769
# Fertig mit Speichern von 32770
# Fertig mit Speichern von 32771
# Fertig mit Speichern von 32772
# Fertig mit Speichern von 32773
# Fertig mit Speichern von 32774
# Fertig mit Speichern von 32775
# Fertig mit Speichern von 32776
# Fertig mit Speichern von 32777
# Fertig mit Speichern von 32778
# Fertig mit Speichern von 32779
# Fertig mit Speichern von 32780
# Fertig mit Speichern von 32781
# Fertig mit Speichern von 32782
# Fertig mit Speichern von 32783
# Fertig mit Speichern von 32784
# Fertig mit Speichern von 32785
# Fertig mit Speichern von 32786
# Fertig mit Speichern von 32787
# Fertig mit Speichern von 32788
# Fertig mit Speichern von 32789
# Fertig mit Speichern von 32790
# Fertig mit Speichern von 32791
# Fertig mit Speichern von 32792
# Fertig mit Speichern von 32793
# Fertig mit Speichern von 32794
# Fertig mit Speichern von 32795
# Fertig mit Speichern von 32796
# Fertig mit Speichern von 32797
# Fertig mit Speichern von 32798
# Fertig mit Speichern von 32799
# Fertig mit Speichern von 32800
# Fertig mit Speichern von 32801
# Fertig mit Speichern von 32802
# Fertig mit Speichern von 32803
# Fertig mit Speichern von 32804
# Fertig mit Speichern von 32805
# Fertig mit Speichern von 32806
# Fertig mit Speichern von 32807
# Fertig mit Speichern von 32808
# Fertig mit Speichern von 32809
# Fertig mit Speichern von 32810
# Fertig mit Speichern von 32811
# Fertig mit Speichern von 32812
# Fertig mit Speichern von 32813
# Fertig mit Speichern von 32814
# Fertig mit Speichern von 32815
# Fertig mit Speichern von 32816
# Fertig mit Speichern von 32817
# Fertig mit Speichern von 32818
# Fertig mit Speichern von 32819
# Fertig mit Speichern von 32820
# Fertig mit Speichern von 32821
# Fertig mit Speichern von 32822
# Fertig mit Speichern von 32823
# Fertig mit Speichern von 32824
# Fertig mit Speichern von 32825
# Fertig mit Speichern von 32826
# Fertig mit Speichern von 32827
# Fertig mit Speichern von 32828
# Fertig mit Speichern von 32829
# Fertig mit Speichern von 32830
# Fertig mit Speichern von 32831
# Fertig mit Speichern von 32832
# Fertig mit Speichern von 32833
# Fertig mit Speichern von 32834
# Fertig mit Speichern von 32835
# Fertig mit Speichern von 32836
# Fertig mit Speichern von 32837
# Fertig mit Speichern von 32838
# Fertig mit Speichern von 32839
# Fertig mit Speichern von 32840
# Fertig mit Speichern von 32841
# Fertig mit Speichern von 32842
# Fertig mit Speichern von 32843
# Fertig mit Speichern von 32844
# Fertig mit Speichern von 32845
# Fertig mit Speichern von 32846
# Fertig mit Speichern von 32847
# Fertig mit Speichern von 32848
# Fertig mit Speichern von 32849
# Fertig mit Speichern von 32850
# Fertig mit Speichern von 32851
# Fertig mit Speichern von 32852
# Fertig mit Speichern von 32853
# Fertig mit Speichern von 32854
# Fertig mit Speichern von 32855
# Fertig mit Speichern von 32856
# Fertig mit Speichern von 32857
# Fertig mit Speichern von 32858
# Fertig mit Speichern von 32859
# Fertig mit Speichern von 32860
# Fertig mit Speichern von 32861
# Fertig mit Speichern von 32862
# Fertig mit Speichern von 32863
# Fertig mit Speichern von 32864
# Fertig mit Speichern von 32865
# Fertig mit Speichern von 32866
# Fertig mit Speichern von 32867
# Fertig mit Speichern von 32868
# Fertig mit Speichern von 32869
# Fertig mit Speichern von 32870
# Fertig mit Speichern von 32871
# Fertig mit Speichern von 32872
# Fertig mit Speichern von 32873
# Fertig mit Speichern von 32874
# Fertig mit Speichern von 32875
# Fertig mit Speichern von 32876
# Fertig mit Speichern von 32877
# Fertig mit Speichern von 32878
# Fertig mit Speichern von 32879
# Fertig mit Speichern von 32880
# Fertig mit Speichern von 32881
# Fertig mit Speichern von 32882
# Fertig mit Speichern von 32883
# Fertig mit Speichern von 32884
# Fertig mit Speichern von 32885
# Fertig mit Speichern von 32886
# Fertig mit Speichern von 32887
# Fertig mit Speichern von 32888
# Fertig mit Speichern von 32889
# Fertig mit Speichern von 32890
# Fertig mit Speichern von 32891
# Fertig mit Speichern von 32892
# Fertig mit Speichern von 32893
# Fertig mit Speichern von 32894
# Fertig mit Speichern von 32895
# Fertig mit Speichern von 32896
# Fertig mit Speichern von 32897
# Fertig mit Speichern von 32898
# Fertig mit Speichern von 32899
# Fertig mit Speichern von 32900
# Fertig mit Speichern von 32901
# Fertig mit Speichern von 32902
# Fertig mit Speichern von 32903
# Fertig mit Speichern von 32904
# Fertig mit Speichern von 32905
# Fertig mit Speichern von 32906
# Fertig mit Speichern von 32907
# Fertig mit Speichern von 32908
# Fertig mit Speichern von 32909
# Fertig mit Speichern von 32910
# Fertig mit Speichern von 32911
# Fertig mit Speichern von 32912
# Fertig mit Speichern von 32913
# Fertig mit Speichern von 32914
# Fertig mit Speichern von 32915
# Fertig mit Speichern von 32916
# Fertig mit Speichern von 32917
# Fertig mit Speichern von 32918
# Fertig mit Speichern von 32919
# Fertig mit Speichern von 32920
# Fertig mit Speichern von 32921
# Fertig mit Speichern von 32922
# Fertig mit Speichern von 32923
# Fertig mit Speichern von 32924
# Fertig mit Speichern von 32925
# Fertig mit Speichern von 32926
# Fertig mit Speichern von 32927
# Fertig mit Speichern von 32928
# Fertig mit Speichern von 32929
# Fertig mit Speichern von 32930
# Fertig mit Speichern von 32931
# Fertig mit Speichern von 32932
# Fertig mit Speichern von 32933
# Fertig mit Speichern von 32934
# Fertig mit Speichern von 32935
# Fertig mit Speichern von 32936
# Fertig mit Speichern von 32937
# Fertig mit Speichern von 32938
# Fertig mit Speichern von 32939
# Fertig mit Speichern von 32940
# Fertig mit Speichern von 32941
# Fertig mit Speichern von 32942
# Fertig mit Speichern von 32943
# Fertig mit Speichern von 32944
# Fertig mit Speichern von 32945
# Fertig mit Speichern von 32946
# Fertig mit Speichern von 32947
# Fertig mit Speichern von 32948
# Fertig mit Speichern von 32949
# Fertig mit Speichern von 32950
# Fertig mit Speichern von 32951
# Fertig mit Speichern von 32952
# Fertig mit Speichern von 32953
# Fertig mit Speichern von 32954

# %%
plot1=training_data
plt.imshow(plot1[0,:,:,1], cmap='binary', interpolation='None')

# %% [markdown]
# Fertig

# %%
test=np.load("C:/Users/Deep Thought/Documents/Python/CNN_Masterarbeit/Training/BeamlikeSingle/BeamlikeS8738.npz")['X']
plt.imshow(test[:,:,1], cmap='binary', interpolation='None')

# %% [markdown]
# cuStrings

# %% [markdown]
# ## Shuffle

# %%
random.shuffle(training_data)

for sample in training_data[:10]:
    print("Eintrag \n", sample[2])

# %% [markdown]
# ## Traingsset

# %%
preX1 =[]
preX2 =[]

for x in training_data:
    preX1.append(x[0])
    preX2.append(x[1])
     
traingset = list(zip(preX1, preX2))


traingset = np.array(traingset).reshape(-1,209,504, 2)
print(len(traingset))

# %%
traingset.shape
#plt.imshow(traingset[0,:,:,0], cmap='binary', interpolation='None')

# %% [markdown]
# ## Truth

# %%
Truth=[]

for x in training_data:
    Truth.append(x[2])


Truth = np.array(Truth)

# %% [markdown]
# ## Safe

# %%
np.savez_compressed('Trainingssets/Training_homogen', Set=fertig)#, Y=Truth)

# %%
batch=20
Namenspacket=[]
for i in range(batch):
    Name = "Trainingspacket{}".format(i)
    Namenspacket.append(Name)

# %% [markdown]
# ## Safe compressed

# %% [markdown]
# So wie ich sehe ist es beim lesen ultra langsam

# %%
np.savez_compressed('Temp/ChargePMT', all_values)
del all_values
print("finish 1")
np.savez_compressed('Temp/ChargeLAPPD', all_values_Lappd)
del all_values_Lappd
print("finish 2")
np.savez_compressed('Temp/TimePMT', time_values)
del time_values
print("finish 3")
np.savez_compressed('Temp/TimeLAPPD', time_values_Lappd)
np.savez_compressed('Temp/TimeLAPPDwithA', A=time_values_Lappd)
del time_values_Lappd
print("finish 4")

# %%
np.savez_compressed('Trainingssets/True', np.array(category_values))
del category_values
